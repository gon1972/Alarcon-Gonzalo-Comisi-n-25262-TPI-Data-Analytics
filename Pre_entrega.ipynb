# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **1_Importar Datasets**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.listdir("/content/drive/MyDrive/Datasets")
# Out:
# ['clientes.csv', 'marketing.csv', 'ventas.csv']

# %%
df_clientes = pd.read_csv('/content/drive/MyDrive/Datasets/clientes.csv')

df_marketing = pd.read_csv('/content/drive/MyDrive/Datasets/marketing.csv')

df_ventas = pd.read_csv('/content/drive/MyDrive/Datasets/ventas.csv')

# %% [markdown]
# ## 🔹 4- Introducción a Pandas: realizar un análisis exploratorio inicial de los DataFrames.

# %% [markdown]
# creamos una funcion analisis

# %%
def Anaisisi_exp(df,arch):
    print(f"Análisis exploratorio de df de {arch}:")

    print(f"Primeras filas {arch}:")
    print(df.head(3))

    print("\nÚltimas filas:")
    print(df.tail())

    print("\nDimensiones (filas, columnas):", df.shape)

    print("\nInformación del DataFrame:")
    print(df.info())

    print("\nEstadísticas descriptivas:")
    print(df.describe().T)

    print("\nTipos de datos:")
    print(df.dtypes)
    print('---------------------------------')
    print('Valores nulos')
    print(df.isna().sum())
    print('---------------------------------')
    print('Valores duplicados')
    print(df.duplicated().sum())

# %%
Anaisisi_exp(df_clientes,'Clientes')
# Out:
# Análisis exploratorio de df de Clientes:
# Primeras filas Clientes:
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
#
# Últimas filas:
#      id_cliente           nombre  edad       ciudad  ingresos
# 562         563    Dione Forsyde    29      Posadas  26757.73
# 563         564      Fleming Gow    39     Santa Fe  43674.96
# 564         565  Jewelle Mabbett    33      Córdoba  30522.64
# 565         566      Lauri Munns    23  Resistencia  31259.14
# 566         567      Micah Matis    31   Corrientes  42927.86
#
# Dimensiones (filas, columnas): (567, 5)
#
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
#  3   ciudad      567 non-null    object
#  4   ingresos    567 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 22.3+ KB
# None
#
# Estadísticas descriptivas:
#             count          mean           std     min       25%       50%  \
# id_cliente  567.0    284.000000    163.823075    1.00    142.50    284.00
# edad        567.0     37.940035     10.202885   20.00     30.00     37.00
# ingresos    567.0  34668.739012  12974.531446  170.29  26015.24  35066.83
#
#                 75%       max
# id_cliente    425.5    567.00
# edad           43.0     81.00
# ingresos    42457.1  88053.01
#
# Tipos de datos:
# id_cliente      int64
# nombre         object
# edad            int64
# ciudad         object
# ingresos      float64
# dtype: object
# ---------------------------------
# Valores nulos
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
# ---------------------------------
# Valores duplicados
# 0

# %%
Anaisisi_exp(df_marketing,'Marketing')
# Out:
# Análisis exploratorio de df de Marketing:
# Primeras filas Marketing:
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
#
# Últimas filas:
#     id_campanha            producto  canal  costo fecha_inicio   fecha_fin
# 85           70          Aspiradora     TV   3.06   13/12/2024  29/12/2024
# 86           89           Televisor     TV   4.98   13/12/2024    8/2/2025
# 87           68   Rincón de plantas     TV   5.81   17/12/2024   14/2/2025
# 88           33            Secadora  Email   3.80   20/12/2024    7/1/2025
# 89           11  Freidora eléctrica   RRSS   5.27   29/12/2024   21/1/2025
#
# Dimensiones (filas, columnas): (90, 6)
#
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
#  4   fecha_inicio  90 non-null     object
#  5   fecha_fin     90 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.3+ KB
# None
#
# Estadísticas descriptivas:
#              count       mean        std   min      25%   50%      75%    max
# id_campanha   90.0  45.500000  26.124701  1.00  23.2500  45.5  67.7500  90.00
# costo         90.0   4.928667   0.947750  2.95   4.3725   4.9   5.5625   7.39
#
# Tipos de datos:
# id_campanha       int64
# producto         object
# canal            object
# costo           float64
# fecha_inicio     object
# fecha_fin        object
# dtype: object
# ---------------------------------
# Valores nulos
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64
# ---------------------------------
# Valores duplicados
# 0

# %%
Anaisisi_exp(df_ventas,'Ventas')
# Out:
# Análisis exploratorio de df de Ventas:
# Primeras filas Ventas:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
#
# Últimas filas:
#       id_venta                producto   precio  cantidad fecha_venta  \
# 3030      1837         Horno eléctrico  $104.12       9.0  30/12/2024
# 3031      2276                  Laptop   $85.27       9.0  30/12/2024
# 3032      2696                  Laptop  $107.81       4.0  30/12/2024
# 3033      2913              Smartphone   $99.85       7.0  30/12/2024
# 3034      2930  Consola de videojuegos   $55.47       6.0  30/12/2024
#
#               categoria
# 3030  Electrodomésticos
# 3031        Electrónica
# 3032        Electrónica
# 3033        Electrónica
# 3034        Electrónica
#
# Dimensiones (filas, columnas): (3035, 6)
#
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3035 non-null   int64
#  1   producto     3035 non-null   object
#  2   precio       3033 non-null   object
#  3   cantidad     3033 non-null   float64
#  4   fecha_venta  3035 non-null   object
#  5   categoria    3035 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 142.4+ KB
# None
#
# Estadísticas descriptivas:
#            count         mean         std  min    25%     50%     75%     max
# id_venta  3035.0  1499.851400  866.465379  1.0  748.5  1502.0  2249.5  3000.0
# cantidad  3033.0     6.496538    3.457250  1.0    3.0     7.0     9.0    12.0
#
# Tipos de datos:
# id_venta         int64
# producto        object
# precio          object
# cantidad       float64
# fecha_venta     object
# categoria       object
# dtype: object
# ---------------------------------
# Valores nulos
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
# ---------------------------------
# Valores duplicados
# 35

# %% [markdown]
# Punto 5 _Calidad de los datos

# %%
def Calidad(df, nombre):
    print()
    print("-"*40)
    print(f"{nombre.upper()} ")
    print("-"*40)

    # ------------------------------------------------
    # Tamaño y tipos de datos
    # ------------------------------------------------
    print("Shape (filas, columnas):", df.shape)
    print("\nTipos de datos:")
    print(df.dtypes)

    # ------------------------------------------------
    # "Calidad" del dataframe (nulos, duplicados, etc)
    # ------------------------------------------------
    print()
    print("-"*40)
    print("Nulos por columna")
    print("-"*40)
    print(df.isna().sum())
    print()
    print("-"*40)
    print("Duplicados (filas exactas):", df.duplicated().sum())
    print("-"*40)

# %%
Calidad(df_ventas, "ventas")
# Out:
# ----------------------------------------
# VENTAS
# ----------------------------------------
# Shape (filas, columnas): (3035, 6)
#
# Tipos de datos:
# id_venta         int64
# producto        object
# precio          object
# cantidad       float64
# fecha_venta     object
# categoria       object
# dtype: object
#
# ----------------------------------------
# Nulos por columna
# ----------------------------------------
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
#
# ----------------------------------------
# Duplicados (filas exactas): 35
# ----------------------------------------

# %% [markdown]
# **Problemas Identificados:**
#
# 1. PROBLEMA CRÍTICO: Formato incorrecto de precios
#
# 2. VALORES NULOS (2 en cada columna)
#
# 3. REGISTROS DUPLICADOS (35 filas)

# %%
Calidad(df_clientes, "clientes")
# Out:
# ----------------------------------------
# CLIENTES
# ----------------------------------------
# Shape (filas, columnas): (567, 5)
#
# Tipos de datos:
# id_cliente      int64
# nombre         object
# edad            int64
# ciudad         object
# ingresos      float64
# dtype: object
#
# ----------------------------------------
# Nulos por columna
# ----------------------------------------
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
#
# ----------------------------------------
# Duplicados (filas exactas): 0
# ----------------------------------------

# %%
Calidad(df_marketing, "marketing")
# Out:
# ----------------------------------------
# MARKETING
# ----------------------------------------
# Shape (filas, columnas): (90, 6)
#
# Tipos de datos:
# id_campanha       int64
# producto         object
# canal            object
# costo           float64
# fecha_inicio     object
# fecha_fin        object
# dtype: object
#
# ----------------------------------------
# Nulos por columna
# ----------------------------------------
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64
#
# ----------------------------------------
# Duplicados (filas exactas): 0
# ----------------------------------------

# %% [markdown]
# Punto 1 Etapa 2 _Limpieza de Datos

# %%
# ============================================
# 🧹 LIMPIEZA Y NORMALIZACIÓN DE LOS DATASETS
# ============================================
# Se limpian y normalizan los DataFrames:
#   ventas, clientes, marketing
# ============================================

# -------------------------------------------------
# 1️⃣ Crear copias independientes para no modificar los originales
# -------------------------------------------------
ventas_clean = df_ventas.copy()
clientes_clean = df_clientes.copy()
marketing_clean = df_marketing.copy()

# -------------------------------------------------
# 2️⃣ Eliminar filas completamente duplicadas
# -------------------------------------------------
ventas_clean = ventas_clean.drop_duplicates()
clientes_clean = clientes_clean.drop_duplicates()
marketing_clean = marketing_clean.drop_duplicates()

# %%
#convierte una columna objeto a flotante
def obj_to_float(dataframe, columna): #funcion que saca el signo $ y la coma ',' del dato y lo convierte a flotante
    if dataframe[columna].dtype == 'object':
      dataframe[columna] = (dataframe[columna].str.replace('$', '')
                          .str.replace(',', '').astype(float))
    return dataframe

# %%
obj_to_float(ventas_clean, 'precio')
# Out:
#       id_venta                producto  precio  cantidad fecha_venta  \
# 0          792       Cuadro decorativo   69.94       5.0  02/01/2024
# 1          811         Lámpara de mesa  105.10       5.0  02/01/2024
# 2         1156                Secadora   97.96       3.0  02/01/2024
# 3         1372                Heladera  114.35       8.0  02/01/2024
# 4         1546                Secadora  106.21       4.0  02/01/2024
# ...        ...                     ...     ...       ...         ...
# 3030      1837         Horno eléctrico  104.12       9.0  30/12/2024
# 3031      2276                  Laptop   85.27       9.0  30/12/2024
# 3032      2696                  Laptop  107.81       4.0  30/12/2024
# 3033      2913              Smartphone   99.85       7.0  30/12/2024
# 3034      2930  Consola de videojuegos   55.47       6.0  30/12/2024
#
#               categoria
# 0            Decoración
# 1            Decoración
# 2     Electrodomésticos
# 3     Electrodomésticos
# 4     Electrodomésticos
# ...                 ...
# 3030  Electrodomésticos
# 3031        Electrónica
# 3032        Electrónica
# 3033        Electrónica
# 3034        Electrónica
#
# [3000 rows x 6 columns]

# %%
def Mostrar_nulos(df): #funcion que me muestra las filas que tienen datos nulos en el dataframe
    for i in range(len(df)):
      if df.iloc[i].isnull().any():
        print(df.iloc[i])
      #print(df.iloc[i]['producto'])

# %%
Mostrar_nulos(ventas_clean)
# Out:
# id_venta                         627
# producto       Elementos de cerámica
# precio                           NaN
# cantidad                         NaN
# fecha_venta               17/01/2024
# categoria                 Decoración
# Name: 136, dtype: object
# id_venta                      2171
# producto       Parlantes Bluetooth
# precio                         NaN
# cantidad                       NaN
# fecha_venta             17/01/2024
# categoria              Electrónica
# Name: 139, dtype: object

# %%
def Borrar_Nulos(df):  #funcion que me borra las filas con datos nulos del dataframe
    indices_to_drop=[]
    for i in range(len(df)):
      if df.iloc[i].isnull().any():
          indices_to_drop.append(i)
    print(indices_to_drop)
    return df.drop(indices_to_drop,inplace=True)

# %%
#ventas_clean.dropna(axis=0,inplace=True)
Borrar_Nulos(ventas_clean) #decido borrar las filas de Ventas con valores nulos porque me complica los calculos
# Out:
# [136, 139]

# %%
#borro duplicados
ventas_clean.drop_duplicates(inplace=True)
Calidad(ventas_clean, "ventas")
# Out:
# ----------------------------------------
# VENTAS
# ----------------------------------------
# Shape (filas, columnas): (2998, 6)
#
# Tipos de datos:
# id_venta         int64
# producto        object
# precio         float64
# cantidad       float64
# fecha_venta     object
# categoria       object
# dtype: object
#
# ----------------------------------------
# Nulos por columna
# ----------------------------------------
# id_venta       0
# producto       0
# precio         0
# cantidad       0
# fecha_venta    0
# categoria      0
# dtype: int64
#
# ----------------------------------------
# Duplicados (filas exactas): 0
# ----------------------------------------

# %%
# -------------------------------------------------
# 3️⃣ Función para limpiar texto en columnas tipo string
# -------------------------------------------------
def Normalizar_texto(df):  #funcion que normaliza el texto de las columnas del tipo 'object'
    for col in df.select_dtypes(include="object").columns:
        # Se agrupan las operaciones entre paréntesis () para escribirlas en varias líneas
        # Python evalúa todo el bloque como una única expresión.
        df[col] = (
            df[col]
            .astype(str)                              # Convierte cualquier tipo a string
            # .astype(str)  → convierte todo a texto; no tiene parámetros adicionales.
            .str.strip()                               # Elimina espacios al inicio y final
            # .str.strip() no necesita argumentos; borra espacios en blanco por defecto.
            .str.replace(r"[\u200b\t\r\n]", "", regex=True)
            # .str.replace(patron, reemplazo, regex=True)
            #   patron: expresión regular que busca caracteres invisibles (\u200b, tabulaciones, saltos)
            #   reemplazo: ""  → los elimina
            #   regex=True indica que 'patron' es una expresión regular.
            .str.replace(" +", " ", regex=True)
            # reemplaza "uno o más espacios consecutivos" por un solo espacio
            .str.title()                               # Convierte a Título: "juan pérez" → "Juan Pérez"
        )
    return df

# %%
def Normalizar_fechas(df): #funcion que convierte las columnas que contienen fechas al tipo datetime
  for col in df.columns:
        if "fecha" in col.lower():  # detecta columnas con la palabra "fecha"
            df[col] = pd.to_datetime(df[col], errors="coerce", dayfirst=True)

# %%
def Normalizar(df):
  Normalizar_texto(df)
  Normalizar_fechas(df)

# %%
Normalizar(ventas_clean)
Calidad(ventas_clean, "ventas") #hago un chequeo
# Out:
# ----------------------------------------
# VENTAS
# ----------------------------------------
# Shape (filas, columnas): (2998, 6)
#
# Tipos de datos:
# id_venta                int64
# producto               object
# precio                float64
# cantidad              float64
# fecha_venta    datetime64[ns]
# categoria              object
# dtype: object
#
# ----------------------------------------
# Nulos por columna
# ----------------------------------------
# id_venta       0
# producto       0
# precio         0
# cantidad       0
# fecha_venta    0
# categoria      0
# dtype: int64
#
# ----------------------------------------
# Duplicados (filas exactas): 0
# ----------------------------------------

# %%
ventas_clean
# Out:
#       id_venta                producto  precio  cantidad fecha_venta  \
# 0          792       Cuadro Decorativo   69.94       5.0  2024-01-02
# 1          811         Lámpara De Mesa  105.10       5.0  2024-01-02
# 2         1156                Secadora   97.96       3.0  2024-01-02
# 3         1372                Heladera  114.35       8.0  2024-01-02
# 4         1546                Secadora  106.21       4.0  2024-01-02
# ...        ...                     ...     ...       ...         ...
# 3030      1837         Horno Eléctrico  104.12       9.0  2024-12-30
# 3031      2276                  Laptop   85.27       9.0  2024-12-30
# 3032      2696                  Laptop  107.81       4.0  2024-12-30
# 3033      2913              Smartphone   99.85       7.0  2024-12-30
# 3034      2930  Consola De Videojuegos   55.47       6.0  2024-12-30
#
#               categoria
# 0            Decoración
# 1            Decoración
# 2     Electrodomésticos
# 3     Electrodomésticos
# 4     Electrodomésticos
# ...                 ...
# 3030  Electrodomésticos
# 3031        Electrónica
# 3032        Electrónica
# 3033        Electrónica
# 3034        Electrónica
#
# [2998 rows x 6 columns]

# %%
Normalizar(clientes_clean)
clientes_clean
# Out:
#      id_cliente               nombre  edad         ciudad  ingresos
# 0             1      Aloysia Screase    44  Mar Del Plata  42294.68
# 1             2  Kristina Scaplehorn    25        Posadas  24735.04
# 2             3       Filip Castagne    50    Resistencia  35744.85
# 3             4          Liuka Luard    39   Bahía Blanca  27647.96
# 4             5        Dore Cockshtt    28        Rosario  28245.65
# ..          ...                  ...   ...            ...       ...
# 562         563        Dione Forsyde    29        Posadas  26757.73
# 563         564          Fleming Gow    39       Santa Fe  43674.96
# 564         565      Jewelle Mabbett    33        Córdoba  30522.64
# 565         566          Lauri Munns    23    Resistencia  31259.14
# 566         567          Micah Matis    31     Corrientes  42927.86
#
# [567 rows x 5 columns]

# %%
Normalizar(marketing_clean)
marketing_clean
# Out:
#     id_campanha            producto  canal  costo fecha_inicio  fecha_fin
# 0            74     Adorno De Pared     Tv   4.81   2024-03-20 2024-05-03
# 1            12              Tablet   Rrss   3.40   2024-03-26 2024-05-13
# 2            32     Lámpara De Mesa  Email   5.54   2024-03-28 2024-04-20
# 3            21          Smartphone   Rrss   6.37   2024-03-29 2024-05-16
# 4            58            Alfombra  Email   4.25   2024-03-31 2024-05-05
# ..          ...                 ...    ...    ...          ...        ...
# 85           70          Aspiradora     Tv   3.06   2024-12-13 2024-12-29
# 86           89           Televisor     Tv   4.98   2024-12-13 2025-02-08
# 87           68   Rincón De Plantas     Tv   5.81   2024-12-17 2025-02-14
# 88           33            Secadora  Email   3.80   2024-12-20 2025-01-07
# 89           11  Freidora Eléctrica   Rrss   5.27   2024-12-29 2025-01-21
#
# [90 rows x 6 columns]

# %% [markdown]
# # Etapa 1 **Actividad 2**

# %% [markdown]
# Realizar un script básico que calcule las ventas mensuales utilizando
# variables y operadores.

# %%
ventas_perf = (  #agregamos a ventas_perf la columna ingreso=cantidad*precio
    ventas_clean
    .assign(
        ingreso = ventas_clean["precio"] * ventas_clean["cantidad"]
    )
)
ventas_perf.head(5)
# Out:
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro Decorativo   69.94       5.0  2024-01-02
# 1       811    Lámpara De Mesa  105.10       5.0  2024-01-02
# 2      1156           Secadora   97.96       3.0  2024-01-02
# 3      1372           Heladera  114.35       8.0  2024-01-02
# 4      1546           Secadora  106.21       4.0  2024-01-02
#
#            categoria  ingreso
# 0         Decoración   349.70
# 1         Decoración   525.50
# 2  Electrodomésticos   293.88
# 3  Electrodomésticos   914.80
# 4  Electrodomésticos   424.84

# %%
totales = {}
for fila in ventas_perf.itertuples(index=False): #recorro por filas ventas_perf
    # Acceso por atributo, con el nombres exacto de las columnas
    # (Si no existe la columna, devuelve NaT/nan)
    fecha = getattr(fila, "fecha_venta", pd.NaT)
    importe = getattr(fila, "ingreso", np.nan)
    #print(fila)
    # Clave (año, mes) y acumulación
    clave = (fecha.year, fecha.month)  # p.ej., (2024, 3)
    totales[clave] = totales.get(clave, 0.0) + float(importe)
totales
# Out:
# {(2024, 1): 129604.99000000003,
#  (2024, 2): 118672.44000000002,
#  (2024, 3): 136779.15,
#  (2024, 4): 128430.69000000005,
#  (2024, 5): 143727.25000000006,
#  (2024, 6): 108480.17000000003,
#  (2024, 7): 116229.97000000004,
#  (2024, 8): 119680.15000000001,
#  (2024, 9): 115787.85000000002,
#  (2024, 10): 112117.13,
#  (2024, 11): 119951.79000000005,
#  (2024, 12): 117631.93999999994}

# %% [markdown]
# # Etapa 1 - Actividad 3
# Estructuras de Datos: Desarrollar un programa que almacene los datos de ventas (producto, precio, cantidad).
#
# Decidir si conviene utilizar diccionarios o listas

# %%
# ----------------------------------------------------
# Iteramos por el dataset, armando una lista de
# diccionarios con el contenido pedido.
# ----------------------------------------------------
registros = [] #voy almacenar el diccionario con los datos pedidos en la lista registros
for fila in ventas_perf.itertuples(index=False):
    if pd.isna(fila.precio) or pd.isna(fila.cantidad) or pd.isna(fila.producto): #si la fila tiene algun dato nulo no lo almaceno , en mi caso los datos nulos ya estan borrados
        continue
    registros.append({
        "producto": fila.producto,
        "precio": float(fila.precio),
        "cantidad": int(fila.cantidad),
    })
registros
# Out:
# [{'producto': 'Cuadro Decorativo', 'precio': 69.94, 'cantidad': 5},
#  {'producto': 'Lámpara De Mesa', 'precio': 105.1, 'cantidad': 5},
#  {'producto': 'Secadora', 'precio': 97.96, 'cantidad': 3},
#  {'producto': 'Heladera', 'precio': 114.35, 'cantidad': 8},
#  {'producto': 'Secadora', 'precio': 106.21, 'cantidad': 4},
#  {'producto': 'Horno Eléctrico', 'precio': 35.35, 'cantidad': 9},
#  {'producto': 'Plancha De Vapor', 'precio': 65.43, 'cantidad': 2},
#  {'producto': 'Proyector', 'precio': 88.17, 'cantidad': 9},
#  {'producto': 'Rincón De Plantas', 'precio': 79.86, 'cantidad': 11},
#  {'producto': 'Candelabro', 'precio': 66.11, 'cantidad': 8},
#  {'producto': 'Aspiradora', 'precio': 95.9, 'cantidad': 5},
#  {'producto': 'Freidora Eléctrica', 'precio': 111.18, 'cantidad': 1},
#  {'producto': 'Aspiradora', 'precio': 70.91, 'cantidad': 2},
#  {'producto': 'Proyector', 'precio': 43.62, 'cantidad': 11},
#  {'producto': 'Tablet', 'precio': 67.97, 'cantidad': 9},
#  {'producto': 'Tablet', 'precio': 74.09, 'cantidad': 5},
#  {'producto': 'Cortinas', 'precio': 62.1, 'cantidad': 4},
#  {'producto': 'Adorno De Pared', 'precio': 71.99, 'cantidad': 9},
#  {'producto': 'Jarrón Decorativo', 'precio': 96.97, 'cantidad': 7},
#  {'producto': 'Cuadro Decorativo', 'precio': 101.92, 'cantidad': 9},
#  {'producto': 'Candelabro', 'precio': 90.7, 'cantidad': 12},
#  {'producto': 'Lavadora', 'precio': 28.41, 'cantidad': 10},
#  {'producto': 'Freidora Eléctrica', 'precio': 122.25, 'cantidad': 11},
#  {'producto': 'Proyector', 'precio': 32.15, 'cantidad': 1},
#  {'producto': 'Cortinas', 'precio': 86.82, 'cantidad': 8},
#  {'producto': 'Cortinas', 'precio': 106.66, 'cantidad': 11},
#  {'producto': 'Jarrón Decorativo', 'precio': 57.22, 'cantidad': 9},
#  {'producto': 'Heladera', 'precio': 109.49, 'cantidad': 11},
#  {'producto': 'Auriculares', 'precio': 84.8, 'cantidad': 10},
#  {'producto': 'Cámara Digital', 'precio': 107.78, 'cantidad': 3},
#  {'producto': 'Lavadora', 'precio': 38.99, 'cantidad': 6},
#  {'producto': 'Cafetera', 'precio': 61.4, 'cantidad': 9},
#  {'producto': 'Consola De Videojuegos', 'precio': 102.57, 'cantidad': 9},
#  {'producto': 'Cámara Digital', 'precio': 50.76, 'cantidad': 3},
#  {'producto': 'Smartphone', 'precio': 87.05, 'cantidad': 5},
#  {'producto': 'Auriculares', 'precio': 100.4, 'cantidad': 6},
#  {'producto': 'Elementos De Cerámica', 'precio': 108.48, 'cantidad': 11},
#  {'producto': 'Espejo Decorativo', 'precio': 82.76, 'cantidad': 8},
#  {'producto': 'Adorno De Pared', 'precio': 57.62, 'cantidad': 6},
#  {'producto': 'Cuadro Decorativo', 'precio': 30.49, 'cantidad': 12},
#  {'producto': 'Candelabro', 'precio': 34.23, 'cantidad': 12},
#  {'producto': 'Plancha De Vapor', 'precio': 33.63, 'cantidad': 10},
#  {'producto': 'Plancha De Vapor', 'precio': 26.91, 'cantidad': 5},
#  {'producto': 'Secadora', 'precio': 95.33, 'cantidad': 11},
#  {'producto': 'Aspiradora', 'precio': 65.55, 'cantidad': 8},
#  {'producto': 'Plancha De Vapor', 'precio': 51.51, 'cantidad': 7},
#  {'producto': 'Auriculares', 'precio': 116.04, 'cantidad': 11},
#  {'producto': 'Smartphone', 'precio': 107.51, 'cantidad': 5},
#  {'producto': 'Consola De Videojuegos', 'precio': 29.49, 'cantidad': 2},
#  {'producto': 'Jarrón Decorativo', 'precio': 37.05, 'cantidad': 4},
#  {'producto': 'Candelabro', 'precio': 57.65, 'cantidad': 6},
#  {'producto': 'Elementos De Cerámica', 'precio': 27.68, 'cantidad': 8},
#  {'producto': 'Cortinas', 'precio': 32.57, 'cantidad': 8},
#  {'producto': 'Aspiradora', 'precio': 50.86, 'cantidad': 4},
#  {'producto': 'Smartphone', 'precio': 54.19, 'cantidad': 12},
#  {'producto': 'Smartphone', 'precio': 70.07, 'cantidad': 11},
#  {'producto': 'Parlantes Bluetooth', 'precio': 87.78, 'cantidad': 1},
#  {'producto': 'Smartwatch', 'precio': 82.18, 'cantidad': 10},
#  {'producto': 'Cortinas', 'precio': 85.71, 'cantidad': 8},
#  {'producto': 'Candelabro', 'precio': 47.22, 'cantidad': 5},
#  {'producto': 'Espejo Decorativo', 'precio': 60.39, 'cantidad': 2},
#  {'producto': 'Jarrón Decorativo', 'precio': 42.46, 'cantidad': 8},
#  {'producto': 'Lámpara De Mesa', 'precio': 79.64, 'cantidad': 11},
#  {'producto': 'Cafetera', 'precio': 29.88, 'cantidad': 10},
#  {'producto': 'Microondas', 'precio': 67.39, 'cantidad': 8},
#  {'producto': 'Aspiradora', 'precio': 99.58, 'cantidad': 7},
#  {'producto': 'Horno Eléctrico', 'precio': 68.53, 'cantidad': 8},
#  {'producto': 'Batidora', 'precio': 39.26, 'cantidad': 11},
#  {'producto': 'Cámara Digital', 'precio': 120.87, 'cantidad': 7},
#  {'producto': 'Alfombra', 'precio': 122.07, 'cantidad': 9},
#  {'producto': 'Espejo Decorativo', 'precio': 96.29, 'cantidad': 9},
#  {'producto': 'Elementos De Cerámica', 'precio': 106.31, 'cantidad': 1},
#  {'producto': 'Adorno De Pared', 'precio': 67.23, 'cantidad': 10},
#  {'producto': 'Jarrón Decorativo', 'precio': 42.83, 'cantidad': 5},
#  {'producto': 'Plancha De Vapor', 'precio': 66.15, 'cantidad': 8},
#  {'producto': 'Aspiradora', 'precio': 36.38, 'cantidad': 5},
#  {'producto': 'Microondas', 'precio': 46.05, 'cantidad': 6},
#  {'producto': 'Rincón De Plantas', 'precio': 31.7, 'cantidad': 11},
#  {'producto': 'Rincón De Plantas', 'precio': 29.88, 'cantidad': 8},
#  {'producto': 'Jarrón Decorativo', 'precio': 87.84, 'cantidad': 7},
#  {'producto': 'Espejo Decorativo', 'precio': 32.34, 'cantidad': 5},
#  {'producto': 'Horno Eléctrico', 'precio': 119.7, 'cantidad': 6},
#  {'producto': 'Aspiradora', 'precio': 36.89, 'cantidad': 7},
#  {'producto': 'Batidora', 'precio': 79.98, 'cantidad': 12},
#  {'producto': 'Lavadora', 'precio': 120.75, 'cantidad': 10},
#  {'producto': 'Smartwatch', 'precio': 48.45, 'cantidad': 2},
#  {'producto': 'Auriculares', 'precio': 117.43, 'cantidad': 11},
#  {'producto': 'Parlantes Bluetooth', 'precio': 29.89, 'cantidad': 9},
#  {'producto': 'Espejo Decorativo', 'precio': 55.61, 'cantidad': 1},
#  {'producto': 'Freidora Eléctrica', 'precio': 52.57, 'cantidad': 11},
#  {'producto': 'Smartwatch', 'precio': 115.0, 'cantidad': 10},
#  {'producto': 'Smartphone', 'precio': 67.93, 'cantidad': 10},
#  {'producto': 'Consola De Videojuegos', 'precio': 110.6, 'cantidad': 12},
#  {'producto': 'Rincón De Plantas', 'precio': 109.33, 'cantidad': 9},
#  {'producto': 'Lámpara De Mesa', 'precio': 35.2, 'cantidad': 6},
#  {'producto': 'Elementos De Cerámica', 'precio': 111.1, 'cantidad': 1},
#  {'producto': 'Lámpara De Mesa', 'precio': 96.79, 'cantidad': 5},
#  {'producto': 'Elementos De Cerámica', 'precio': 102.62, 'cantidad': 3},
#  {'producto': 'Cafetera', 'precio': 35.73, 'cantidad': 12},
#  {'producto': 'Televisor', 'precio': 57.34, 'cantidad': 1},
#  {'producto': 'Tablet', 'precio': 32.3, 'cantidad': 1},
#  {'producto': 'Adorno De Pared', 'precio': 90.21, 'cantidad': 2},
#  {'producto': 'Espejo Decorativo', 'precio': 115.45, 'cantidad': 7},
#  {'producto': 'Rincón De Plantas', 'precio': 64.67, 'cantidad': 10},
#  {'producto': 'Espejo Decorativo', 'precio': 98.26, 'cantidad': 1},
#  {'producto': 'Lavadora', 'precio': 43.98, 'cantidad': 6},
#  {'producto': 'Batidora', 'precio': 96.78, 'cantidad': 12},
#  {'producto': 'Cafetera', 'precio': 123.96, 'cantidad': 9},
#  {'producto': 'Lavadora', 'precio': 84.8, 'cantidad': 3},
#  {'producto': 'Auriculares', 'precio': 27.36, 'cantidad': 10},
#  {'producto': 'Lámpara De Mesa', 'precio': 76.32, 'cantidad': 9},
#  {'producto': 'Cortinas', 'precio': 118.69, 'cantidad': 9},
#  {'producto': 'Adorno De Pared', 'precio': 101.48, 'cantidad': 9},
#  {'producto': 'Elementos De Cerámica', 'precio': 74.35, 'cantidad': 5},
#  {'producto': 'Freidora Eléctrica', 'precio': 119.46, 'cantidad': 2},
#  {'producto': 'Smartwatch', 'precio': 75.65, 'cantidad': 5},
#  {'producto': 'Laptop', 'precio': 31.69, 'cantidad': 1},
#  {'producto': 'Consola De Videojuegos', 'precio': 99.14, 'cantidad': 6},
#  {'producto': 'Smartwatch', 'precio': 30.38, 'cantidad': 8},
#  {'producto': 'Smartphone', 'precio': 95.73, 'cantidad': 5},
#  {'producto': 'Tablet', 'precio': 117.47, 'cantidad': 2},
#  {'producto': 'Espejo Decorativo', 'precio': 75.93, 'cantidad': 10},
#  {'producto': 'Espejo Decorativo', 'precio': 101.91, 'cantidad': 3},
#  {'producto': 'Cuadro Decorativo', 'precio': 30.59, 'cantidad': 1},
#  {'producto': 'Cuadro Decorativo', 'precio': 40.97, 'cantidad': 11},
#  {'producto': 'Plancha De Vapor', 'precio': 98.55, 'cantidad': 6},
#  {'producto': 'Freidora Eléctrica', 'precio': 83.95, 'cantidad': 8},
#  {'producto': 'Plancha De Vapor', 'precio': 86.65, 'cantidad': 6},
#  {'producto': 'Proyector', 'precio': 107.98, 'cantidad': 6},
#  {'producto': 'Consola De Videojuegos', 'precio': 31.57, 'cantidad': 1},
#  {'producto': 'Cámara Digital', 'precio': 38.37, 'cantidad': 9},
#  {'producto': 'Proyector', 'precio': 115.19, 'cantidad': 11},
#  {'producto': 'Auriculares', 'precio': 80.29, 'cantidad': 2},
#  {'producto': 'Lámpara De Mesa', 'precio': 58.32, 'cantidad': 10},
#  {'producto': 'Rincón De Plantas', 'precio': 81.5, 'cantidad': 1},
#  {'producto': 'Rincón De Plantas', 'precio': 87.4, 'cantidad': 9},
#  {'producto': 'Jarrón Decorativo', 'precio': 106.89, 'cantidad': 6},
#  {'producto': 'Plancha De Vapor', 'precio': 94.53, 'cantidad': 2},
#  {'producto': 'Tablet', 'precio': 69.35, 'cantidad': 4},
#  {'producto': 'Televisor', 'precio': 117.53, 'cantidad': 9},
#  {'producto': 'Smartwatch', 'precio': 76.47, 'cantidad': 7},
#  {'producto': 'Adorno De Pared', 'precio': 81.76, 'cantidad': 5},
#  {'producto': 'Rincón De Plantas', 'precio': 80.17, 'cantidad': 3},
#  {'producto': 'Secadora', 'precio': 102.73, 'cantidad': 6},
#  {'producto': 'Plancha De Vapor', 'precio': 45.14, 'cantidad': 1},
#  {'producto': 'Proyector', 'precio': 84.1, 'cantidad': 11},
#  {'producto': 'Auriculares', 'precio': 63.67, 'cantidad': 5},
#  {'producto': 'Cámara Digital', 'precio': 119.43, 'cantidad': 5},
#  {'producto': 'Laptop', 'precio': 81.74, 'cantidad': 10},
#  {'producto': 'Parlantes Bluetooth', 'precio': 69.4, 'cantidad': 1},
#  {'producto': 'Televisor', 'precio': 84.96, 'cantidad': 5},
#  {'producto': 'Adorno De Pared', 'precio': 76.92, 'cantidad': 6},
#  {'producto': 'Lámpara De Mesa', 'precio': 52.95, 'cantidad': 6},
#  {'producto': 'Jarrón Decorativo', 'precio': 103.13, 'cantidad': 8},
#  {'producto': 'Espejo Decorativo', 'precio': 123.21, 'cantidad': 7},
#  {'producto': 'Alfombra', 'precio': 33.48, 'cantidad': 12},
#  {'producto': 'Lámpara De Mesa', 'precio': 85.23, 'cantidad': 6},
#  {'producto': 'Lavadora', 'precio': 97.73, 'cantidad': 12},
#  {'producto': 'Cafetera', 'precio': 98.21, 'cantidad': 11},
#  {'producto': 'Secadora', 'precio': 27.45, 'cantidad': 10},
#  {'producto': 'Parlantes Bluetooth', 'precio': 42.98, 'cantidad': 7},
#  {'producto': 'Lámpara De Mesa', 'precio': 69.47, 'cantidad': 8},
#  {'producto': 'Rincón De Plantas', 'precio': 85.75, 'cantidad': 3},
#  {'producto': 'Horno Eléctrico', 'precio': 98.42, 'cantidad': 8},
#  {'producto': 'Batidora', 'precio': 95.59, 'cantidad': 3},
#  {'producto': 'Cámara Digital', 'precio': 108.61, 'cantidad': 2},
#  {'producto': 'Smartwatch', 'precio': 83.01, 'cantidad': 11},
#  {'producto': 'Parlantes Bluetooth', 'precio': 40.74, 'cantidad': 6},
#  {'producto': 'Cámara Digital', 'precio': 71.45, 'cantidad': 5},
#  {'producto': 'Cámara Digital', 'precio': 91.13, 'cantidad': 8},
#  {'producto': 'Lámpara De Mesa', 'precio': 121.72, 'cantidad': 8},
#  {'producto': 'Jarrón Decorativo', 'precio': 91.53, 'cantidad': 12},
#  {'producto': 'Horno Eléctrico', 'precio': 103.57, 'cantidad': 1},
#  {'producto': 'Plancha De Vapor', 'precio': 27.61, 'cantidad': 7},
#  {'producto': 'Lavadora', 'precio': 67.2, 'cantidad': 11},
#  {'producto': 'Secadora', 'precio': 84.5, 'cantidad': 11},
#  {'producto': 'Aspiradora', 'precio': 104.86, 'cantidad': 8},
#  {'producto': 'Cafetera', 'precio': 51.16, 'cantidad': 12},
#  {'producto': 'Consola De Videojuegos', 'precio': 87.23, 'cantidad': 5},
#  {'producto': 'Cuadro Decorativo', 'precio': 29.17, 'cantidad': 1},
#  {'producto': 'Elementos De Cerámica', 'precio': 83.81, 'cantidad': 6},
#  {'producto': 'Jarrón Decorativo', 'precio': 26.97, 'cantidad': 5},
#  {'producto': 'Secadora', 'precio': 91.54, 'cantidad': 2},
#  {'producto': 'Cafetera', 'precio': 45.98, 'cantidad': 3},
#  {'producto': 'Freidora Eléctrica', 'precio': 48.68, 'cantidad': 8},
#  {'producto': 'Adorno De Pared', 'precio': 51.56, 'cantidad': 5},
#  {'producto': 'Lámpara De Mesa', 'precio': 26.42, 'cantidad': 2},
#  {'producto': 'Lámpara De Mesa', 'precio': 96.37, 'cantidad': 5},
#  {'producto': 'Elementos De Cerámica', 'precio': 117.34, 'cantidad': 1},
#  {'producto': 'Cafetera', 'precio': 86.79, 'cantidad': 3},
#  {'producto': 'Consola De Videojuegos', 'precio': 102.4, 'cantidad': 2},
#  {'producto': 'Lámpara De Mesa', 'precio': 57.35, 'cantidad': 12},
#  {'producto': 'Jarrón Decorativo', 'precio': 66.27, 'cantidad': 1},
#  {'producto': 'Cortinas', 'precio': 90.87, 'cantidad': 4},
#  {'producto': 'Rincón De Plantas', 'precio': 89.47, 'cantidad': 2},
#  {'producto': 'Lavadora', 'precio': 108.37, 'cantidad': 1},
#  {'producto': 'Secadora', 'precio': 40.63, 'cantidad': 3},
#  {'producto': 'Horno Eléctrico', 'precio': 45.79, 'cantidad': 7},
#  {'producto': 'Tablet', 'precio': 27.98, 'cantidad': 8},
#  {'producto': 'Smartphone', 'precio': 91.39, 'cantidad': 7},
#  {'producto': 'Smartphone', 'precio': 27.32, 'cantidad': 7},
#  {'producto': 'Televisor', 'precio': 26.7, 'cantidad': 9},
#  {'producto': 'Alfombra', 'precio': 71.14, 'cantidad': 2},
#  {'producto': 'Espejo Decorativo', 'precio': 123.22, 'cantidad': 10},
#  {'producto': 'Cafetera', 'precio': 96.94, 'cantidad': 4},
#  {'producto': 'Lavadora', 'precio': 66.16, 'cantidad': 4},
#  {'producto': 'Microondas', 'precio': 39.45, 'cantidad': 9},
#  {'producto': 'Parlantes Bluetooth', 'precio': 100.6, 'cantidad': 6},
#  {'producto': 'Consola De Videojuegos', 'precio': 109.68, 'cantidad': 5},
#  {'producto': 'Televisor', 'precio': 77.83, 'cantidad': 8},
#  {'producto': 'Proyector', 'precio': 70.1, 'cantidad': 10},
#  {'producto': 'Auriculares', 'precio': 93.37, 'cantidad': 10},
#  {'producto': 'Smartwatch', 'precio': 29.15, 'cantidad': 2},
#  {'producto': 'Espejo Decorativo', 'precio': 52.58, 'cantidad': 9},
#  {'producto': 'Lámpara De Mesa', 'precio': 70.6, 'cantidad': 6},
#  {'producto': 'Elementos De Cerámica', 'precio': 106.39, 'cantidad': 6},
#  {'producto': 'Espejo Decorativo', 'precio': 110.02, 'cantidad': 1},
#  {'producto': 'Cafetera', 'precio': 120.32, 'cantidad': 9},
#  {'producto': 'Televisor', 'precio': 89.27, 'cantidad': 8},
#  {'producto': 'Auriculares', 'precio': 31.03, 'cantidad': 9},
#  {'producto': 'Rincón De Plantas', 'precio': 120.32, 'cantidad': 1},
#  {'producto': 'Adorno De Pared', 'precio': 103.79, 'cantidad': 2},
#  {'producto': 'Cortinas', 'precio': 37.02, 'cantidad': 5},
#  {'producto': 'Plancha De Vapor', 'precio': 95.1, 'cantidad': 2},
#  {'producto': 'Aspiradora', 'precio': 28.79, 'cantidad': 12},
#  {'producto': 'Horno Eléctrico', 'precio': 53.46, 'cantidad': 4},
#  {'producto': 'Auriculares', 'precio': 47.24, 'cantidad': 9},
#  {'producto': 'Smartwatch', 'precio': 54.84, 'cantidad': 1},
#  {'producto': 'Televisor', 'precio': 33.19, 'cantidad': 9},
#  {'producto': 'Laptop', 'precio': 30.31, 'cantidad': 2},
#  {'producto': 'Elementos De Cerámica', 'precio': 28.22, 'cantidad': 4},
#  {'producto': 'Lámpara De Mesa', 'precio': 95.46, 'cantidad': 10},
#  {'producto': 'Cuadro Decorativo', 'precio': 111.56, 'cantidad': 9},
#  {'producto': 'Batidora', 'precio': 103.27, 'cantidad': 3},
#  {'producto': 'Smartphone', 'precio': 34.5, 'cantidad': 1},
#  {'producto': 'Laptop', 'precio': 33.07, 'cantidad': 10},
#  {'producto': 'Smartphone', 'precio': 115.81, 'cantidad': 1},
#  {'producto': 'Espejo Decorativo', 'precio': 29.77, 'cantidad': 11},
#  {'producto': 'Cafetera', 'precio': 88.56, 'cantidad': 8},
#  {'producto': 'Lavadora', 'precio': 76.5, 'cantidad': 3},
#  {'producto': 'Smartwatch', 'precio': 100.06, 'cantidad': 7},
#  {'producto': 'Consola De Videojuegos', 'precio': 43.35, 'cantidad': 8},
#  {'producto': 'Auriculares', 'precio': 53.45, 'cantidad': 8},
#  {'producto': 'Smartphone', 'precio': 121.22, 'cantidad': 6},
#  {'producto': 'Consola De Videojuegos', 'precio': 72.39, 'cantidad': 1},
#  {'producto': 'Smartwatch', 'precio': 122.68, 'cantidad': 1},
#  {'producto': 'Smartphone', 'precio': 121.0, 'cantidad': 12},
#  {'producto': 'Secadora', 'precio': 109.0, 'cantidad': 11},
#  {'producto': 'Secadora', 'precio': 47.91, 'cantidad': 1},
#  {'producto': 'Lavadora', 'precio': 43.52, 'cantidad': 7},
#  {'producto': 'Auriculares', 'precio': 56.56, 'cantidad': 4},
#  {'producto': 'Smartphone', 'precio': 59.33, 'cantidad': 2},
#  {'producto': 'Televisor', 'precio': 94.98, 'cantidad': 2},
#  {'producto': 'Tablet', 'precio': 41.96, 'cantidad': 9},
#  {'producto': 'Auriculares', 'precio': 115.2, 'cantidad': 1},
#  {'producto': 'Adorno De Pared', 'precio': 83.1, 'cantidad': 5},
#  {'producto': 'Cuadro Decorativo', 'precio': 59.6, 'cantidad': 5},
#  {'producto': 'Lámpara De Mesa', 'precio': 78.89, 'cantidad': 11},
#  {'producto': 'Elementos De Cerámica', 'precio': 52.17, 'cantidad': 7},
#  {'producto': 'Cuadro Decorativo', 'precio': 78.93, 'cantidad': 4},
#  {'producto': 'Lavadora', 'precio': 92.36, 'cantidad': 1},
#  {'producto': 'Plancha De Vapor', 'precio': 101.96, 'cantidad': 10},
#  {'producto': 'Aspiradora', 'precio': 74.11, 'cantidad': 11},
#  {'producto': 'Freidora Eléctrica', 'precio': 121.77, 'cantidad': 12},
#  {'producto': 'Cafetera', 'precio': 63.54, 'cantidad': 9},
#  {'producto': 'Auriculares', 'precio': 35.74, 'cantidad': 11},
#  {'producto': 'Auriculares', 'precio': 119.77, 'cantidad': 5},
#  {'producto': 'Laptop', 'precio': 93.91, 'cantidad': 2},
#  {'producto': 'Espejo Decorativo', 'precio': 44.37, 'cantidad': 2},
#  {'producto': 'Rincón De Plantas', 'precio': 81.92, 'cantidad': 10},
#  {'producto': 'Cafetera', 'precio': 108.33, 'cantidad': 2},
#  {'producto': 'Aspiradora', 'precio': 112.38, 'cantidad': 10},
#  {'producto': 'Microondas', 'precio': 89.16, 'cantidad': 5},
#  {'producto': 'Proyector', 'precio': 76.17, 'cantidad': 12},
#  {'producto': 'Auriculares', 'precio': 123.41, 'cantidad': 8},
#  {'producto': 'Consola De Videojuegos', 'precio': 89.96, 'cantidad': 2},
#  {'producto': 'Adorno De Pared', 'precio': 45.84, 'cantidad': 10},
#  {'producto': 'Elementos De Cerámica', 'precio': 108.86, 'cantidad': 6},
#  {'producto': 'Rincón De Plantas', 'precio': 27.95, 'cantidad': 7},
#  {'producto': 'Lámpara De Mesa', 'precio': 41.6, 'cantidad': 12},
#  {'producto': 'Plancha De Vapor', 'precio': 47.6, 'cantidad': 10},
#  {'producto': 'Proyector', 'precio': 111.74, 'cantidad': 6},
#  {'producto': 'Auriculares', 'precio': 26.0, 'cantidad': 9},
#  {'producto': 'Smartphone', 'precio': 88.43, 'cantidad': 2},
#  {'producto': 'Proyector', 'precio': 62.88, 'cantidad': 7},
#  {'producto': 'Laptop', 'precio': 109.23, 'cantidad': 7},
#  {'producto': 'Smartwatch', 'precio': 108.99, 'cantidad': 10},
#  {'producto': 'Lámpara De Mesa', 'precio': 30.03, 'cantidad': 8},
#  {'producto': 'Lámpara De Mesa', 'precio': 76.33, 'cantidad': 10},
#  {'producto': 'Alfombra', 'precio': 51.29, 'cantidad': 2},
#  {'producto': 'Secadora', 'precio': 42.81, 'cantidad': 7},
#  {'producto': 'Batidora', 'precio': 77.53, 'cantidad': 4},
#  {'producto': 'Cámara Digital', 'precio': 117.11, 'cantidad': 9},
#  {'producto': 'Smartwatch', 'precio': 49.23, 'cantidad': 4},
#  {'producto': 'Smartwatch', 'precio': 81.32, 'cantidad': 6},
#  {'producto': 'Parlantes Bluetooth', 'precio': 110.42, 'cantidad': 2},
#  {'producto': 'Jarrón Decorativo', 'precio': 104.16, 'cantidad': 10},
#  {'producto': 'Espejo Decorativo', 'precio': 117.99, 'cantidad': 3},
#  {'producto': 'Aspiradora', 'precio': 69.31, 'cantidad': 10},
#  {'producto': 'Lavadora', 'precio': 38.61, 'cantidad': 10},
#  {'producto': 'Secadora', 'precio': 84.24, 'cantidad': 3},
#  {'producto': 'Auriculares', 'precio': 109.07, 'cantidad': 4},
#  {'producto': 'Televisor', 'precio': 49.23, 'cantidad': 4},
#  {'producto': 'Jarrón Decorativo', 'precio': 70.51, 'cantidad': 12},
#  {'producto': 'Adorno De Pared', 'precio': 100.32, 'cantidad': 10},
#  {'producto': 'Elementos De Cerámica', 'precio': 83.52, 'cantidad': 12},
#  {'producto': 'Lámpara De Mesa', 'precio': 33.9, 'cantidad': 4},
#  {'producto': 'Freidora Eléctrica', 'precio': 48.52, 'cantidad': 4},
#  {'producto': 'Lavadora', 'precio': 123.28, 'cantidad': 8},
#  {'producto': 'Freidora Eléctrica', 'precio': 81.99, 'cantidad': 1},
#  {'producto': 'Smartwatch', 'precio': 72.38, 'cantidad': 1},
#  {'producto': 'Laptop', 'precio': 47.57, 'cantidad': 4},
#  {'producto': 'Aspiradora', 'precio': 65.0, 'cantidad': 9},
#  {'producto': 'Microondas', 'precio': 82.58, 'cantidad': 9},
#  {'producto': 'Cafetera', 'precio': 123.27, 'cantidad': 4},
#  {'producto': 'Cámara Digital', 'precio': 57.81, 'cantidad': 10},
#  {'producto': 'Smartwatch', 'precio': 45.98, 'cantidad': 3},
#  {'producto': 'Laptop', 'precio': 70.59, 'cantidad': 9},
#  {'producto': 'Cámara Digital', 'precio': 89.53, 'cantidad': 9},
#  {'producto': 'Cámara Digital', 'precio': 102.83, 'cantidad': 5},
#  {'producto': 'Lámpara De Mesa', 'precio': 124.57, 'cantidad': 3},
#  {'producto': 'Espejo Decorativo', 'precio': 122.11, 'cantidad': 7},
#  {'producto': 'Cuadro Decorativo', 'precio': 42.09, 'cantidad': 12},
#  {'producto': 'Adorno De Pared', 'precio': 103.74, 'cantidad': 5},
#  {'producto': 'Alfombra', 'precio': 102.72, 'cantidad': 2},
#  {'producto': 'Plancha De Vapor', 'precio': 48.48, 'cantidad': 10},
#  {'producto': 'Cafetera', 'precio': 109.97, 'cantidad': 2},
#  {'producto': 'Aspiradora', 'precio': 124.82, 'cantidad': 3},
#  {'producto': 'Auriculares', 'precio': 42.67, 'cantidad': 6},
#  {'producto': 'Espejo Decorativo', 'precio': 30.11, 'cantidad': 12},
#  {'producto': 'Elementos De Cerámica', 'precio': 47.0, 'cantidad': 2},
#  {'producto': 'Alfombra', 'precio': 50.02, 'cantidad': 12},
#  {'producto': 'Adorno De Pared', 'precio': 112.03, 'cantidad': 9},
#  {'producto': 'Lámpara De Mesa', 'precio': 79.91, 'cantidad': 8},
#  {'producto': 'Freidora Eléctrica', 'precio': 58.69, 'cantidad': 4},
#  {'producto': 'Batidora', 'precio': 79.14, 'cantidad': 10},
#  {'producto': 'Smartwatch', 'precio': 64.98, 'cantidad': 11},
#  {'producto': 'Lámpara De Mesa', 'precio': 58.38, 'cantidad': 4},
#  {'producto': 'Freidora Eléctrica', 'precio': 95.71, 'cantidad': 4},
#  {'producto': 'Freidora Eléctrica', 'precio': 51.37, 'cantidad': 9},
#  {'producto': 'Auriculares', 'precio': 54.54, 'cantidad': 9},
#  {'producto': 'Smartwatch', 'precio': 97.01, 'cantidad': 4},
#  {'producto': 'Smartwatch', 'precio': 110.23, 'cantidad': 11},
#  {'producto': 'Alfombra', 'precio': 78.47, 'cantidad': 1},
#  {'producto': 'Cuadro Decorativo', 'precio': 52.83, 'cantidad': 12},
#  {'producto': 'Lámpara De Mesa', 'precio': 99.71, 'cantidad': 3},
#  {'producto': 'Elementos De Cerámica', 'precio': 116.82, 'cantidad': 3},
#  {'producto': 'Adorno De Pared', 'precio': 91.48, 'cantidad': 9},
#  {'producto': 'Lámpara De Mesa', 'precio': 87.04, 'cantidad': 1},
#  {'producto': 'Aspiradora', 'precio': 26.11, 'cantidad': 9},
#  {'producto': 'Secadora', 'precio': 45.43, 'cantidad': 11},
#  {'producto': 'Secadora', 'precio': 115.57, 'cantidad': 12},
#  {'producto': 'Smartphone', 'precio': 49.34, 'cantidad': 12},
#  {'producto': 'Smartphone', 'precio': 59.33, 'cantidad': 5},
#  {'producto': 'Smartphone', 'precio': 74.8, 'cantidad': 5},
#  {'producto': 'Smartphone', 'precio': 97.62, 'cantidad': 1},
#  {'producto': 'Espejo Decorativo', 'precio': 81.16, 'cantidad': 2},
#  {'producto': 'Alfombra', 'precio': 108.67, 'cantidad': 4},
#  {'producto': 'Elementos De Cerámica', 'precio': 35.97, 'cantidad': 2},
#  {'producto': 'Cuadro Decorativo', 'precio': 109.69, 'cantidad': 8},
#  {'producto': 'Plancha De Vapor', 'precio': 101.57, 'cantidad': 10},
#  {'producto': 'Freidora Eléctrica', 'precio': 83.07, 'cantidad': 6},
#  {'producto': 'Consola De Videojuegos', 'precio': 110.79, 'cantidad': 8},
#  {'producto': 'Televisor', 'precio': 112.58, 'cantidad': 5},
#  {'producto': 'Cuadro Decorativo', 'precio': 71.97, 'cantidad': 12},
#  {'producto': 'Cuadro Decorativo', 'precio': 72.08, 'cantidad': 11},
#  {'producto': 'Adorno De Pared', 'precio': 37.5, 'cantidad': 3},
#  {'producto': 'Microondas', 'precio': 96.35, 'cantidad': 3},
#  {'producto': 'Televisor', 'precio': 97.3, 'cantidad': 9},
#  {'producto': 'Auriculares', 'precio': 57.41, 'cantidad': 4},
#  {'producto': 'Auriculares', 'precio': 74.7, 'cantidad': 10},
#  {'producto': 'Cortinas', 'precio': 40.19, 'cantidad': 3},
#  {'producto': 'Proyector', 'precio': 108.52, 'cantidad': 12},
#  {'producto': 'Proyector', 'precio': 26.52, 'cantidad': 3},
#  {'producto': 'Proyector', 'precio': 63.33, 'cantidad': 10},
#  {'producto': 'Laptop', 'precio': 31.94, 'cantidad': 11},
#  {'producto': 'Proyector', 'precio': 33.84, 'cantidad': 5},
#  {'producto': 'Lámpara De Mesa', 'precio': 113.01, 'cantidad': 7},
#  {'producto': 'Cortinas', 'precio': 92.84, 'cantidad': 1},
#  {'producto': 'Cortinas', 'precio': 64.96, 'cantidad': 1},
#  {'producto': 'Jarrón Decorativo', 'precio': 82.89, 'cantidad': 10},
#  {'producto': 'Cafetera', 'precio': 79.98, 'cantidad': 2},
#  {'producto': 'Secadora', 'precio': 69.17, 'cantidad': 6},
#  {'producto': 'Auriculares', 'precio': 45.97, 'cantidad': 12},
#  {'producto': 'Parlantes Bluetooth', 'precio': 123.36, 'cantidad': 5},
#  {'producto': 'Parlantes Bluetooth', 'precio': 101.08, 'cantidad': 7},
#  {'producto': 'Cuadro Decorativo', 'precio': 87.42, 'cantidad': 7},
#  {'producto': 'Elementos De Cerámica', 'precio': 38.25, 'cantidad': 1},
#  {'producto': 'Cortinas', 'precio': 109.32, 'cantidad': 7},
#  {'producto': 'Microondas', 'precio': 98.65, 'cantidad': 2},
#  {'producto': 'Televisor', 'precio': 62.8, 'cantidad': 8},
#  {'producto': 'Proyector', 'precio': 65.41, 'cantidad': 7},
#  {'producto': 'Plancha De Vapor', 'precio': 48.23, 'cantidad': 5},
#  {'producto': 'Lavadora', 'precio': 120.53, 'cantidad': 5},
#  {'producto': 'Cafetera', 'precio': 97.97, 'cantidad': 2},
#  {'producto': 'Auriculares', 'precio': 44.56, 'cantidad': 8},
#  {'producto': 'Auriculares', 'precio': 81.96, 'cantidad': 2},
#  {'producto': 'Auriculares', 'precio': 39.92, 'cantidad': 4},
#  {'producto': 'Elementos De Cerámica', 'precio': 108.86, 'cantidad': 6},
#  {'producto': 'Espejo Decorativo', 'precio': 59.36, 'cantidad': 4},
#  {'producto': 'Secadora', 'precio': 64.11, 'cantidad': 4},
#  {'producto': 'Microondas', 'precio': 95.91, 'cantidad': 4},
#  {'producto': 'Aspiradora', 'precio': 38.1, 'cantidad': 9},
#  {'producto': 'Laptop', 'precio': 76.02, 'cantidad': 10},
#  {'producto': 'Auriculares', 'precio': 72.37, 'cantidad': 8},
#  {'producto': 'Auriculares', 'precio': 61.61, 'cantidad': 4},
#  {'producto': 'Alfombra', 'precio': 36.14, 'cantidad': 8},
#  {'producto': 'Cortinas', 'precio': 98.73, 'cantidad': 10},
#  {'producto': 'Cortinas', 'precio': 76.78, 'cantidad': 7},
#  {'producto': 'Cuadro Decorativo', 'precio': 120.22, 'cantidad': 5},
#  {'producto': 'Rincón De Plantas', 'precio': 96.23, 'cantidad': 8},
#  {'producto': 'Jarrón Decorativo', 'precio': 96.35, 'cantidad': 10},
#  {'producto': 'Freidora Eléctrica', 'precio': 95.5, 'cantidad': 4},
#  {'producto': 'Lavadora', 'precio': 96.75, 'cantidad': 3},
#  {'producto': 'Plancha De Vapor', 'precio': 79.95, 'cantidad': 10},
#  {'producto': 'Laptop', 'precio': 61.22, 'cantidad': 2},
#  {'producto': 'Televisor', 'precio': 69.69, 'cantidad': 5},
#  {'producto': 'Cámara Digital', 'precio': 63.35, 'cantidad': 1},
#  {'producto': 'Espejo Decorativo', 'precio': 101.38, 'cantidad': 6},
#  {'producto': 'Cuadro Decorativo', 'precio': 110.99, 'cantidad': 8},
#  {'producto': 'Rincón De Plantas', 'precio': 74.58, 'cantidad': 11},
#  {'producto': 'Rincón De Plantas', 'precio': 58.34, 'cantidad': 2},
#  {'producto': 'Rincón De Plantas', 'precio': 29.09, 'cantidad': 12},
#  {'producto': 'Cuadro Decorativo', 'precio': 52.23, 'cantidad': 10},
#  {'producto': 'Elementos De Cerámica', 'precio': 76.94, 'cantidad': 12},
#  {'producto': 'Cuadro Decorativo', 'precio': 84.63, 'cantidad': 5},
#  {'producto': 'Batidora', 'precio': 79.1, 'cantidad': 4},
#  {'producto': 'Cafetera', 'precio': 99.1, 'cantidad': 10},
#  {'producto': 'Cafetera', 'precio': 45.67, 'cantidad': 4},
#  {'producto': 'Cámara Digital', 'precio': 28.16, 'cantidad': 4},
#  {'producto': 'Laptop', 'precio': 51.15, 'cantidad': 2},
#  {'producto': 'Consola De Videojuegos', 'precio': 63.26, 'cantidad': 2},
#  {'producto': 'Smartphone', 'precio': 116.25, 'cantidad': 8},
#  {'producto': 'Rincón De Plantas', 'precio': 59.16, 'cantidad': 11},
#  {'producto': 'Rincón De Plantas', 'precio': 63.23, 'cantidad': 7},
#  {'producto': 'Adorno De Pared', 'precio': 90.05, 'cantidad': 1},
#  {'producto': 'Freidora Eléctrica', 'precio': 117.97, 'cantidad': 6},
#  {'producto': 'Secadora', 'precio': 80.16, 'cantidad': 9},
#  {'producto': 'Microondas', 'precio': 60.46, 'cantidad': 5},
#  {'producto': 'Plancha De Vapor', 'precio': 35.94, 'cantidad': 12},
#  {'producto': 'Plancha De Vapor', 'precio': 75.08, 'cantidad': 6},
#  {'producto': 'Plancha De Vapor', 'precio': 45.5, 'cantidad': 12},
#  {'producto': 'Smartphone', 'precio': 32.6, 'cantidad': 8},
#  {'producto': 'Televisor', 'precio': 49.01, 'cantidad': 3},
#  {'producto': 'Smartphone', 'precio': 53.67, 'cantidad': 6},
#  {'producto': 'Elementos De Cerámica', 'precio': 63.79, 'cantidad': 1},
#  {'producto': 'Rincón De Plantas', 'precio': 36.28, 'cantidad': 12},
#  {'producto': 'Lámpara De Mesa', 'precio': 44.78, 'cantidad': 4},
#  {'producto': 'Rincón De Plantas', 'precio': 111.8, 'cantidad': 5},
#  {'producto': 'Cafetera', 'precio': 124.68, 'cantidad': 1},
#  {'producto': 'Cafetera', 'precio': 53.82, 'cantidad': 7},
#  {'producto': 'Laptop', 'precio': 99.0, 'cantidad': 11},
#  {'producto': 'Smartphone', 'precio': 59.99, 'cantidad': 12},
#  {'producto': 'Cortinas', 'precio': 36.75, 'cantidad': 12},
#  {'producto': 'Cuadro Decorativo', 'precio': 35.48, 'cantidad': 3},
#  {'producto': 'Lámpara De Mesa', 'precio': 31.24, 'cantidad': 1},
#  {'producto': 'Lámpara De Mesa', 'precio': 66.48, 'cantidad': 1},
#  {'producto': 'Cuadro Decorativo', 'precio': 110.51, 'cantidad': 11},
#  {'producto': 'Microondas', 'precio': 52.26, 'cantidad': 8},
#  {'producto': 'Proyector', 'precio': 52.52, 'cantidad': 3},
#  {'producto': 'Smartphone', 'precio': 32.58, 'cantidad': 9},
#  {'producto': 'Parlantes Bluetooth', 'precio': 26.71, 'cantidad': 12},
#  {'producto': 'Cámara Digital', 'precio': 61.4, 'cantidad': 7},
#  {'producto': 'Alfombra', 'precio': 58.82, 'cantidad': 9},
#  {'producto': 'Elementos De Cerámica', 'precio': 60.17, 'cantidad': 7},
#  {'producto': 'Lámpara De Mesa', 'precio': 48.58, 'cantidad': 11},
#  {'producto': 'Adorno De Pared', 'precio': 75.13, 'cantidad': 6},
#  {'producto': 'Cafetera', 'precio': 113.84, 'cantidad': 2},
#  {'producto': 'Cafetera', 'precio': 68.89, 'cantidad': 6},
#  {'producto': 'Horno Eléctrico', 'precio': 31.5, 'cantidad': 4},
#  {'producto': 'Smartwatch', 'precio': 35.41, 'cantidad': 3},
#  {'producto': 'Smartwatch', 'precio': 29.39, 'cantidad': 11},
#  {'producto': 'Laptop', 'precio': 29.49, 'cantidad': 8},
#  {'producto': 'Smartphone', 'precio': 28.64, 'cantidad': 2},
#  {'producto': 'Microondas', 'precio': 91.81, 'cantidad': 9},
#  {'producto': 'Cafetera', 'precio': 76.0, 'cantidad': 7},
#  {'producto': 'Auriculares', 'precio': 117.03, 'cantidad': 6},
#  {'producto': 'Televisor', 'precio': 70.17, 'cantidad': 7},
#  {'producto': 'Proyector', 'precio': 74.59, 'cantidad': 4},
#  {'producto': 'Smartwatch', 'precio': 47.21, 'cantidad': 1},
#  {'producto': 'Cuadro Decorativo', 'precio': 124.2, 'cantidad': 10},
#  {'producto': 'Lámpara De Mesa', 'precio': 106.58, 'cantidad': 3},
#  {'producto': 'Elementos De Cerámica', 'precio': 67.37, 'cantidad': 2},
#  {'producto': 'Plancha De Vapor', 'precio': 45.37, 'cantidad': 6},
#  {'producto': 'Proyector', 'precio': 65.89, 'cantidad': 4},
#  {'producto': 'Parlantes Bluetooth', 'precio': 62.77, 'cantidad': 6},
#  {'producto': 'Cuadro Decorativo', 'precio': 106.12, 'cantidad': 3},
#  {'producto': 'Lámpara De Mesa', 'precio': 62.47, 'cantidad': 6},
#  {'producto': 'Lámpara De Mesa', 'precio': 46.25, 'cantidad': 12},
#  {'producto': 'Lavadora', 'precio': 67.17, 'cantidad': 9},
#  {'producto': 'Cafetera', 'precio': 92.62, 'cantidad': 8},
#  {'producto': 'Lavadora', 'precio': 46.18, 'cantidad': 10},
#  {'producto': 'Cafetera', 'precio': 49.32, 'cantidad': 3},
#  {'producto': 'Tablet', 'precio': 82.71, 'cantidad': 7},
#  {'producto': 'Consola De Videojuegos', 'precio': 31.09, 'cantidad': 1},
#  {'producto': 'Tablet', 'precio': 99.82, 'cantidad': 8},
#  {'producto': 'Alfombra', 'precio': 87.85, 'cantidad': 2},
#  {'producto': 'Adorno De Pared', 'precio': 27.92, 'cantidad': 5},
#  {'producto': 'Cuadro Decorativo', 'precio': 112.56, 'cantidad': 9},
#  {'producto': 'Secadora', 'precio': 41.84, 'cantidad': 8},
#  {'producto': 'Cafetera', 'precio': 100.92, 'cantidad': 1},
#  {'producto': 'Plancha De Vapor', 'precio': 122.77, 'cantidad': 10},
#  {'producto': 'Batidora', 'precio': 69.74, 'cantidad': 8},
#  {'producto': 'Microondas', 'precio': 108.34, 'cantidad': 12},
#  {'producto': 'Batidora', 'precio': 63.5, 'cantidad': 3},
#  {'producto': 'Consola De Videojuegos', 'precio': 81.69, 'cantidad': 4},
#  {'producto': 'Auriculares', 'precio': 104.59, 'cantidad': 9},
#  {'producto': 'Cámara Digital', 'precio': 117.71, 'cantidad': 2},
#  {'producto': 'Lámpara De Mesa', 'precio': 119.69, 'cantidad': 10},
#  {'producto': 'Jarrón Decorativo', 'precio': 108.99, 'cantidad': 6},
#  {'producto': 'Cuadro Decorativo', 'precio': 34.33, 'cantidad': 11},
#  {'producto': 'Batidora', 'precio': 122.02, 'cantidad': 12},
#  {'producto': 'Plancha De Vapor', 'precio': 114.48, 'cantidad': 4},
#  {'producto': 'Aspiradora', 'precio': 88.95, 'cantidad': 11},
#  {'producto': 'Tablet', 'precio': 78.87, 'cantidad': 5},
#  {'producto': 'Smartphone', 'precio': 116.89, 'cantidad': 6},
#  {'producto': 'Lámpara De Mesa', 'precio': 85.58, 'cantidad': 11},
#  {'producto': 'Batidora', 'precio': 82.18, 'cantidad': 6},
#  {'producto': 'Microondas', 'precio': 54.11, 'cantidad': 7},
#  {'producto': 'Proyector', 'precio': 66.66, 'cantidad': 6},
#  {'producto': 'Elementos De Cerámica', 'precio': 92.88, 'cantidad': 10},
#  {'producto': 'Cortinas', 'precio': 39.63, 'cantidad': 2},
#  {'producto': 'Jarrón Decorativo', 'precio': 80.34, 'cantidad': 7},
#  {'producto': 'Rincón De Plantas', 'precio': 85.49, 'cantidad': 2},
#  {'producto': 'Batidora', 'precio': 61.72, 'cantidad': 8},
#  {'producto': 'Televisor', 'precio': 81.31, 'cantidad': 9},
#  {'producto': 'Televisor', 'precio': 123.48, 'cantidad': 7},
#  {'producto': 'Cámara Digital', 'precio': 31.52, 'cantidad': 8},
#  {'producto': 'Rincón De Plantas', 'precio': 70.24, 'cantidad': 7},
#  {'producto': 'Cortinas', 'precio': 122.97, 'cantidad': 5},
#  {'producto': 'Espejo Decorativo', 'precio': 64.37, 'cantidad': 1},
#  {'producto': 'Adorno De Pared', 'precio': 77.65, 'cantidad': 1},
#  {'producto': 'Alfombra', 'precio': 118.35, 'cantidad': 3},
#  {'producto': 'Auriculares', 'precio': 55.2, 'cantidad': 10},
#  {'producto': 'Cortinas', 'precio': 108.74, 'cantidad': 3},
#  {'producto': 'Jarrón Decorativo', 'precio': 112.06, 'cantidad': 1},
#  {'producto': 'Cafetera', 'precio': 38.44, 'cantidad': 7},
#  {'producto': 'Secadora', 'precio': 33.89, 'cantidad': 7},
#  {'producto': 'Freidora Eléctrica', 'precio': 109.97, 'cantidad': 7},
#  {'producto': 'Cafetera', 'precio': 106.32, 'cantidad': 1},
#  {'producto': 'Proyector', 'precio': 77.06, 'cantidad': 1},
#  {'producto': 'Adorno De Pared', 'precio': 44.91, 'cantidad': 1},
#  {'producto': 'Jarrón Decorativo', 'precio': 57.23, 'cantidad': 5},
#  {'producto': 'Jarrón Decorativo', 'precio': 115.58, 'cantidad': 12},
#  {'producto': 'Lavadora', 'precio': 108.53, 'cantidad': 10},
#  {'producto': 'Secadora', 'precio': 59.04, 'cantidad': 11},
#  {'producto': 'Freidora Eléctrica', 'precio': 67.75, 'cantidad': 2},
#  {'producto': 'Microondas', 'precio': 81.63, 'cantidad': 6},
#  {'producto': 'Smartphone', 'precio': 124.01, 'cantidad': 12},
#  {'producto': 'Televisor', 'precio': 33.14, 'cantidad': 1},
#  {'producto': 'Lámpara De Mesa', 'precio': 115.77, 'cantidad': 11},
#  {'producto': 'Secadora', 'precio': 59.33, 'cantidad': 8},
#  {'producto': 'Proyector', 'precio': 40.99, 'cantidad': 2},
#  {'producto': 'Smartwatch', 'precio': 100.57, 'cantidad': 9},
#  {'producto': 'Smartwatch', 'precio': 100.96, 'cantidad': 10},
#  {'producto': 'Televisor', 'precio': 119.68, 'cantidad': 2},
#  {'producto': 'Cuadro Decorativo', 'precio': 45.04, 'cantidad': 10},
#  {'producto': 'Alfombra', 'precio': 44.66, 'cantidad': 7},
#  {'producto': 'Lámpara De Mesa', 'precio': 34.26, 'cantidad': 11},
#  {'producto': 'Horno Eléctrico', 'precio': 70.09, 'cantidad': 1},
#  {'producto': 'Cafetera', 'precio': 39.31, 'cantidad': 11},
#  {'producto': 'Cafetera', 'precio': 117.43, 'cantidad': 8},
#  {'producto': 'Consola De Videojuegos', 'precio': 117.47, 'cantidad': 8},
#  {'producto': 'Consola De Videojuegos', 'precio': 118.87, 'cantidad': 6},
#  {'producto': 'Espejo Decorativo', 'precio': 70.36, 'cantidad': 5},
#  {'producto': 'Cortinas', 'precio': 84.55, 'cantidad': 5},
#  {'producto': 'Rincón De Plantas', 'precio': 46.49, 'cantidad': 1},
#  {'producto': 'Alfombra', 'precio': 97.14, 'cantidad': 1},
#  {'producto': 'Batidora', 'precio': 29.86, 'cantidad': 4},
#  {'producto': 'Aspiradora', 'precio': 60.42, 'cantidad': 11},
#  {'producto': 'Horno Eléctrico', 'precio': 53.29, 'cantidad': 12},
#  {'producto': 'Batidora', 'precio': 65.59, 'cantidad': 9},
#  {'producto': 'Smartphone', 'precio': 37.11, 'cantidad': 3},
#  {'producto': 'Cortinas', 'precio': 39.67, 'cantidad': 2},
#  {'producto': 'Adorno De Pared', 'precio': 34.68, 'cantidad': 5},
#  {'producto': 'Alfombra', 'precio': 102.81, 'cantidad': 9},
#  {'producto': 'Alfombra', 'precio': 48.99, 'cantidad': 8},
#  {'producto': 'Batidora', 'precio': 48.8, 'cantidad': 11},
#  {'producto': 'Microondas', 'precio': 69.57, 'cantidad': 1},
#  {'producto': 'Aspiradora', 'precio': 86.29, 'cantidad': 12},
#  {'producto': 'Televisor', 'precio': 68.99, 'cantidad': 10},
#  {'producto': 'Tablet', 'precio': 54.19, 'cantidad': 3},
#  {'producto': 'Auriculares', 'precio': 79.29, 'cantidad': 6},
#  {'producto': 'Auriculares', 'precio': 51.71, 'cantidad': 3},
#  {'producto': 'Laptop', 'precio': 39.13, 'cantidad': 8},
#  {'producto': 'Smartphone', 'precio': 118.6, 'cantidad': 11},
#  {'producto': 'Jarrón Decorativo', 'precio': 51.08, 'cantidad': 11},
#  {'producto': 'Lámpara De Mesa', 'precio': 96.41, 'cantidad': 11},
#  {'producto': 'Elementos De Cerámica', 'precio': 29.05, 'cantidad': 10},
#  {'producto': 'Rincón De Plantas', 'precio': 32.05, 'cantidad': 4},
#  {'producto': 'Batidora', 'precio': 85.59, 'cantidad': 5},
#  {'producto': 'Batidora', 'precio': 49.37, 'cantidad': 9},
#  {'producto': 'Plancha De Vapor', 'precio': 28.85, 'cantidad': 11},
#  {'producto': 'Cafetera', 'precio': 96.84, 'cantidad': 11},
#  {'producto': 'Freidora Eléctrica', 'precio': 77.13, 'cantidad': 4},
#  {'producto': 'Plancha De Vapor', 'precio': 102.6, 'cantidad': 12},
#  {'producto': 'Auriculares', 'precio': 55.17, 'cantidad': 4},
#  {'producto': 'Lámpara De Mesa', 'precio': 89.87, 'cantidad': 12},
#  {'producto': 'Alfombra', 'precio': 65.09, 'cantidad': 5},
#  {'producto': 'Plancha De Vapor', 'precio': 40.78, 'cantidad': 12},
#  {'producto': 'Freidora Eléctrica', 'precio': 61.53, 'cantidad': 11},
#  {'producto': 'Horno Eléctrico', 'precio': 59.05, 'cantidad': 8},
#  {'producto': 'Aspiradora', 'precio': 42.94, 'cantidad': 2},
#  {'producto': 'Laptop', 'precio': 43.34, 'cantidad': 8},
#  {'producto': 'Espejo Decorativo', 'precio': 85.04, 'cantidad': 9},
#  {'producto': 'Lámpara De Mesa', 'precio': 46.89, 'cantidad': 2},
#  {'producto': 'Elementos De Cerámica', 'precio': 41.55, 'cantidad': 3},
#  {'producto': 'Heladera', 'precio': 121.85, 'cantidad': 10},
#  {'producto': 'Cafetera', 'precio': 30.7, 'cantidad': 5},
#  {'producto': 'Lavadora', 'precio': 114.72, 'cantidad': 9},
#  {'producto': 'Televisor', 'precio': 31.8, 'cantidad': 10},
#  {'producto': 'Proyector', 'precio': 76.15, 'cantidad': 11},
#  {'producto': 'Espejo Decorativo', 'precio': 79.98, 'cantidad': 10},
#  {'producto': 'Espejo Decorativo', 'precio': 74.95, 'cantidad': 3},
#  {'producto': 'Jarrón Decorativo', 'precio': 80.88, 'cantidad': 12},
#  {'producto': 'Microondas', 'precio': 71.13, 'cantidad': 12},
#  {'producto': 'Plancha De Vapor', 'precio': 122.04, 'cantidad': 1},
#  {'producto': 'Lavadora', 'precio': 53.77, 'cantidad': 7},
#  {'producto': 'Plancha De Vapor', 'precio': 76.32, 'cantidad': 5},
#  {'producto': 'Heladera', 'precio': 58.45, 'cantidad': 1},
#  {'producto': 'Secadora', 'precio': 110.04, 'cantidad': 11},
#  {'producto': 'Smartphone', 'precio': 113.88, 'cantidad': 9},
#  {'producto': 'Cámara Digital', 'precio': 80.06, 'cantidad': 3},
#  {'producto': 'Smartwatch', 'precio': 119.73, 'cantidad': 12},
#  {'producto': 'Smartwatch', 'precio': 89.27, 'cantidad': 6},
#  {'producto': 'Adorno De Pared', 'precio': 36.55, 'cantidad': 3},
#  {'producto': 'Microondas', 'precio': 40.9, 'cantidad': 9},
#  {'producto': 'Horno Eléctrico', 'precio': 109.73, 'cantidad': 9},
#  {'producto': 'Heladera', 'precio': 56.94, 'cantidad': 2},
#  {'producto': 'Cafetera', 'precio': 104.66, 'cantidad': 11},
#  {'producto': 'Televisor', 'precio': 66.57, 'cantidad': 5},
#  {'producto': 'Cámara Digital', 'precio': 112.14, 'cantidad': 3},
#  {'producto': 'Smartphone', 'precio': 124.82, 'cantidad': 5},
#  {'producto': 'Smartwatch', 'precio': 53.93, 'cantidad': 7},
#  {'producto': 'Televisor', 'precio': 56.81, 'cantidad': 9},
#  {'producto': 'Parlantes Bluetooth', 'precio': 80.25, 'cantidad': 10},
#  {'producto': 'Elementos De Cerámica', 'precio': 94.94, 'cantidad': 12},
#  {'producto': 'Jarrón Decorativo', 'precio': 51.39, 'cantidad': 10},
#  {'producto': 'Cuadro Decorativo', 'precio': 78.76, 'cantidad': 10},
#  {'producto': 'Elementos De Cerámica', 'precio': 75.27, 'cantidad': 4},
#  {'producto': 'Microondas', 'precio': 119.61, 'cantidad': 2},
#  {'producto': 'Televisor', 'precio': 55.66, 'cantidad': 3},
#  {'producto': 'Consola De Videojuegos', 'precio': 122.4, 'cantidad': 1},
#  {'producto': 'Auriculares', 'precio': 100.07, 'cantidad': 11},
#  {'producto': 'Cámara Digital', 'precio': 90.34, 'cantidad': 1},
#  {'producto': 'Auriculares', 'precio': 42.5, 'cantidad': 7},
#  {'producto': 'Consola De Videojuegos', 'precio': 29.14, 'cantidad': 10},
#  {'producto': 'Espejo Decorativo', 'precio': 78.46, 'cantidad': 7},
#  {'producto': 'Cortinas', 'precio': 115.79, 'cantidad': 1},
#  {'producto': 'Lámpara De Mesa', 'precio': 51.5, 'cantidad': 1},
#  {'producto': 'Batidora', 'precio': 39.73, 'cantidad': 11},
#  {'producto': 'Plancha De Vapor', 'precio': 101.57, 'cantidad': 7},
#  {'producto': 'Lavadora', 'precio': 31.36, 'cantidad': 7},
#  {'producto': 'Smartwatch', 'precio': 99.78, 'cantidad': 1},
#  {'producto': 'Consola De Videojuegos', 'precio': 108.0, 'cantidad': 9},
#  {'producto': 'Smartphone', 'precio': 105.63, 'cantidad': 6},
#  {'producto': 'Proyector', 'precio': 120.5, 'cantidad': 4},
#  {'producto': 'Proyector', 'precio': 89.06, 'cantidad': 1},
#  {'producto': 'Cuadro Decorativo', 'precio': 70.89, 'cantidad': 11},
#  {'producto': 'Lámpara De Mesa', 'precio': 29.32, 'cantidad': 3},
#  {'producto': 'Jarrón Decorativo', 'precio': 98.11, 'cantidad': 2},
#  {'producto': 'Horno Eléctrico', 'precio': 116.21, 'cantidad': 8},
#  {'producto': 'Aspiradora', 'precio': 102.32, 'cantidad': 2},
#  {'producto': 'Batidora', 'precio': 111.44, 'cantidad': 3},
#  {'producto': 'Lavadora', 'precio': 33.31, 'cantidad': 10},
#  {'producto': 'Auriculares', 'precio': 70.16, 'cantidad': 11},
#  {'producto': 'Cámara Digital', 'precio': 45.12, 'cantidad': 6},
#  {'producto': 'Cámara Digital', 'precio': 92.0, 'cantidad': 10},
#  {'producto': 'Rincón De Plantas', 'precio': 101.62, 'cantidad': 9},
#  {'producto': 'Elementos De Cerámica', 'precio': 97.51, 'cantidad': 5},
#  {'producto': 'Alfombra', 'precio': 96.21, 'cantidad': 11},
#  {'producto': 'Cuadro Decorativo', 'precio': 55.89, 'cantidad': 10},
#  {'producto': 'Cortinas', 'precio': 63.98, 'cantidad': 11},
#  {'producto': 'Aspiradora', 'precio': 80.38, 'cantidad': 9},
#  {'producto': 'Auriculares', 'precio': 78.28, 'cantidad': 6},
#  {'producto': 'Auriculares', 'precio': 101.08, 'cantidad': 10},
#  {'producto': 'Laptop', 'precio': 40.16, 'cantidad': 3},
#  {'producto': 'Smartphone', 'precio': 107.84, 'cantidad': 11},
#  {'producto': 'Jarrón Decorativo', 'precio': 109.29, 'cantidad': 10},
#  {'producto': 'Lámpara De Mesa', 'precio': 40.05, 'cantidad': 2},
#  {'producto': 'Lámpara De Mesa', 'precio': 103.06, 'cantidad': 9},
#  {'producto': 'Microondas', 'precio': 72.86, 'cantidad': 10},
#  {'producto': 'Horno Eléctrico', 'precio': 82.36, 'cantidad': 2},
#  {'producto': 'Cámara Digital', 'precio': 68.66, 'cantidad': 12},
#  {'producto': 'Cámara Digital', 'precio': 85.45, 'cantidad': 3},
#  {'producto': 'Cámara Digital', 'precio': 65.62, 'cantidad': 8},
#  {'producto': 'Elementos De Cerámica', 'precio': 89.17, 'cantidad': 4},
#  {'producto': 'Cortinas', 'precio': 73.65, 'cantidad': 2},
#  {'producto': 'Jarrón Decorativo', 'precio': 112.4, 'cantidad': 9},
#  {'producto': 'Cortinas', 'precio': 64.93, 'cantidad': 10},
#  {'producto': 'Alfombra', 'precio': 48.79, 'cantidad': 11},
#  {'producto': 'Adorno De Pared', 'precio': 116.42, 'cantidad': 6},
#  {'producto': 'Freidora Eléctrica', 'precio': 88.59, 'cantidad': 8},
#  {'producto': 'Freidora Eléctrica', 'precio': 43.14, 'cantidad': 12},
#  {'producto': 'Televisor', 'precio': 34.89, 'cantidad': 12},
#  {'producto': 'Consola De Videojuegos', 'precio': 54.04, 'cantidad': 8},
#  {'producto': 'Alfombra', 'precio': 115.12, 'cantidad': 12},
#  {'producto': 'Adorno De Pared', 'precio': 79.13, 'cantidad': 7},
#  {'producto': 'Plancha De Vapor', 'precio': 76.04, 'cantidad': 5},
#  {'producto': 'Horno Eléctrico', 'precio': 103.51, 'cantidad': 7},
#  {'producto': 'Horno Eléctrico', 'precio': 116.79, 'cantidad': 12},
#  {'producto': 'Freidora Eléctrica', 'precio': 87.85, 'cantidad': 4},
#  {'producto': 'Consola De Videojuegos', 'precio': 44.36, 'cantidad': 10},
#  {'producto': 'Consola De Videojuegos', 'precio': 50.77, 'cantidad': 10},
#  {'producto': 'Parlantes Bluetooth', 'precio': 32.86, 'cantidad': 11},
#  {'producto': 'Parlantes Bluetooth', 'precio': 88.65, 'cantidad': 9},
#  {'producto': 'Laptop', 'precio': 27.65, 'cantidad': 11},
#  {'producto': 'Alfombra', 'precio': 63.14, 'cantidad': 2},
#  {'producto': 'Adorno De Pared', 'precio': 96.59, 'cantidad': 6},
#  {'producto': 'Alfombra', 'precio': 36.17, 'cantidad': 1},
#  {'producto': 'Heladera', 'precio': 103.34, 'cantidad': 8},
#  {'producto': 'Freidora Eléctrica', 'precio': 124.0, 'cantidad': 5},
#  {'producto': 'Proyector', 'precio': 116.66, 'cantidad': 12},
#  {'producto': 'Consola De Videojuegos', 'precio': 94.73, 'cantidad': 1},
#  {'producto': 'Televisor', 'precio': 40.83, 'cantidad': 3},
#  {'producto': 'Auriculares', 'precio': 124.63, 'cantidad': 10},
#  {'producto': 'Smartphone', 'precio': 114.94, 'cantidad': 11},
#  {'producto': 'Horno Eléctrico', 'precio': 53.09, 'cantidad': 3},
#  {'producto': 'Plancha De Vapor', 'precio': 68.28, 'cantidad': 9},
#  {'producto': 'Laptop', 'precio': 68.84, 'cantidad': 11},
#  {'producto': 'Adorno De Pared', 'precio': 71.67, 'cantidad': 4},
#  {'producto': 'Rincón De Plantas', 'precio': 63.1, 'cantidad': 11},
#  {'producto': 'Heladera', 'precio': 112.52, 'cantidad': 4},
#  {'producto': 'Heladera', 'precio': 31.42, 'cantidad': 1},
#  {'producto': 'Aspiradora', 'precio': 102.92, 'cantidad': 5},
#  {'producto': 'Smartphone', 'precio': 118.8, 'cantidad': 2},
#  {'producto': 'Proyector', 'precio': 96.7, 'cantidad': 3},
#  {'producto': 'Consola De Videojuegos', 'precio': 72.78, 'cantidad': 9},
#  {'producto': 'Televisor', 'precio': 46.04, 'cantidad': 3},
#  {'producto': 'Consola De Videojuegos', 'precio': 96.21, 'cantidad': 11},
#  {'producto': 'Lámpara De Mesa', 'precio': 42.6, 'cantidad': 1},
#  {'producto': 'Alfombra', 'precio': 83.25, 'cantidad': 1},
#  {'producto': 'Lámpara De Mesa', 'precio': 40.3, 'cantidad': 2},
#  {'producto': 'Cuadro Decorativo', 'precio': 100.52, 'cantidad': 9},
#  {'producto': 'Microondas', 'precio': 71.38, 'cantidad': 1},
#  {'producto': 'Cafetera', 'precio': 39.33, 'cantidad': 10},
#  {'producto': 'Laptop', 'precio': 80.84, 'cantidad': 9},
#  {'producto': 'Televisor', 'precio': 67.37, 'cantidad': 4},
#  {'producto': 'Jarrón Decorativo', 'precio': 115.95, 'cantidad': 1},
#  {'producto': 'Lámpara De Mesa', 'precio': 83.61, 'cantidad': 1},
#  {'producto': 'Microondas', 'precio': 49.65, 'cantidad': 5},
#  {'producto': 'Cafetera', 'precio': 63.49, 'cantidad': 7},
#  {'producto': 'Lavadora', 'precio': 81.34, 'cantidad': 4},
#  {'producto': 'Aspiradora', 'precio': 78.77, 'cantidad': 1},
#  {'producto': 'Televisor', 'precio': 42.72, 'cantidad': 1},
#  {'producto': 'Cuadro Decorativo', 'precio': 56.45, 'cantidad': 12},
#  {'producto': 'Lámpara De Mesa', 'precio': 116.13, 'cantidad': 8},
#  {'producto': 'Rincón De Plantas', 'precio': 82.59, 'cantidad': 8},
#  {'producto': 'Lámpara De Mesa', 'precio': 46.83, 'cantidad': 3},
#  {'producto': 'Freidora Eléctrica', 'precio': 113.11, 'cantidad': 12},
#  {'producto': 'Lavadora', 'precio': 44.12, 'cantidad': 10},
#  {'producto': 'Rincón De Plantas', 'precio': 93.66, 'cantidad': 10},
#  {'producto': 'Adorno De Pared', 'precio': 103.9, 'cantidad': 8},
#  {'producto': 'Freidora Eléctrica', 'precio': 90.31, 'cantidad': 6},
#  {'producto': 'Microondas', 'precio': 63.01, 'cantidad': 8},
#  {'producto': 'Lavadora', 'precio': 37.25, 'cantidad': 11},
#  {'producto': 'Microondas', 'precio': 32.18, 'cantidad': 7},
#  {'producto': 'Consola De Videojuegos', 'precio': 123.72, 'cantidad': 3},
#  {'producto': 'Televisor', 'precio': 55.97, 'cantidad': 7},
#  {'producto': 'Auriculares', 'precio': 47.12, 'cantidad': 12},
#  {'producto': 'Smartwatch', 'precio': 115.3, 'cantidad': 3},
#  {'producto': 'Laptop', 'precio': 122.13, 'cantidad': 11},
#  {'producto': 'Lámpara De Mesa', 'precio': 44.88, 'cantidad': 1},
#  {'producto': 'Plancha De Vapor', 'precio': 33.15, 'cantidad': 2},
#  {'producto': 'Freidora Eléctrica', 'precio': 44.33, 'cantidad': 10},
#  {'producto': 'Auriculares', 'precio': 120.46, 'cantidad': 8},
#  {'producto': 'Tablet', 'precio': 35.84, 'cantidad': 11},
#  {'producto': 'Laptop', 'precio': 71.74, 'cantidad': 8},
#  {'producto': 'Smartphone', 'precio': 111.41, 'cantidad': 7},
#  {'producto': 'Tablet', 'precio': 75.89, 'cantidad': 11},
#  {'producto': 'Cortinas', 'precio': 98.15, 'cantidad': 7},
#  {'producto': 'Lámpara De Mesa', 'precio': 41.81, 'cantidad': 9},
#  {'producto': 'Lámpara De Mesa', 'precio': 33.37, 'cantidad': 3},
#  {'producto': 'Jarrón Decorativo', 'precio': 53.53, 'cantidad': 7},
#  {'producto': 'Jarrón Decorativo', 'precio': 40.48, 'cantidad': 11},
#  {'producto': 'Freidora Eléctrica', 'precio': 95.13, 'cantidad': 8},
#  {'producto': 'Freidora Eléctrica', 'precio': 84.29, 'cantidad': 10},
#  {'producto': 'Microondas', 'precio': 112.89, 'cantidad': 1},
#  {'producto': 'Cafetera', 'precio': 116.78, 'cantidad': 6},
#  {'producto': 'Televisor', 'precio': 101.98, 'cantidad': 7},
#  {'producto': 'Parlantes Bluetooth', 'precio': 77.95, 'cantidad': 6},
#  {'producto': 'Adorno De Pared', 'precio': 87.52, 'cantidad': 8},
#  {'producto': 'Cuadro Decorativo', 'precio': 27.99, 'cantidad': 5},
#  {'producto': 'Heladera', 'precio': 58.58, 'cantidad': 4},
#  {'producto': 'Consola De Videojuegos', 'precio': 102.41, 'cantidad': 5},
#  {'producto': 'Smartphone', 'precio': 103.69, 'cantidad': 1},
#  {'producto': 'Auriculares', 'precio': 89.29, 'cantidad': 2},
#  {'producto': 'Alfombra', 'precio': 72.91, 'cantidad': 1},
#  {'producto': 'Espejo Decorativo', 'precio': 34.64, 'cantidad': 12},
#  {'producto': 'Cafetera', 'precio': 42.4, 'cantidad': 10},
#  {'producto': 'Cafetera', 'precio': 110.21, 'cantidad': 4},
#  {'producto': 'Horno Eléctrico', 'precio': 27.61, 'cantidad': 6},
#  {'producto': 'Cafetera', 'precio': 58.68, 'cantidad': 4},
#  {'producto': 'Secadora', 'precio': 39.42, 'cantidad': 9},
#  {'producto': 'Batidora', 'precio': 121.14, 'cantidad': 3},
#  {'producto': 'Microondas', 'precio': 96.24, 'cantidad': 4},
#  {'producto': 'Cortinas', 'precio': 27.05, 'cantidad': 3},
#  {'producto': 'Lámpara De Mesa', 'precio': 98.22, 'cantidad': 4},
#  {'producto': 'Lámpara De Mesa', 'precio': 35.26, 'cantidad': 9},
#  {'producto': 'Adorno De Pared', 'precio': 64.18, 'cantidad': 7},
#  {'producto': 'Espejo Decorativo', 'precio': 43.51, 'cantidad': 1},
#  {'producto': 'Lámpara De Mesa', 'precio': 39.86, 'cantidad': 6},
#  {'producto': 'Cafetera', 'precio': 91.58, 'cantidad': 11},
#  {'producto': 'Plancha De Vapor', 'precio': 99.08, 'cantidad': 11},
#  {'producto': 'Freidora Eléctrica', 'precio': 82.46, 'cantidad': 4},
#  {'producto': 'Horno Eléctrico', 'precio': 40.58, 'cantidad': 5},
#  {'producto': 'Smartwatch', 'precio': 38.84, 'cantidad': 7},
#  {'producto': 'Parlantes Bluetooth', 'precio': 70.68, 'cantidad': 5},
#  {'producto': 'Televisor', 'precio': 81.42, 'cantidad': 9},
#  {'producto': 'Cuadro Decorativo', 'precio': 87.93, 'cantidad': 11},
#  {'producto': 'Elementos De Cerámica', 'precio': 61.12, 'cantidad': 9},
#  {'producto': 'Adorno De Pared', 'precio': 49.3, 'cantidad': 2},
#  {'producto': 'Adorno De Pared', 'precio': 33.1, 'cantidad': 1},
#  {'producto': 'Lámpara De Mesa', 'precio': 86.82, 'cantidad': 10},
#  {'producto': 'Horno Eléctrico', 'precio': 116.05, 'cantidad': 11},
#  {'producto': 'Secadora', 'precio': 31.56, 'cantidad': 11},
#  {'producto': 'Cafetera', 'precio': 68.97, 'cantidad': 8},
#  {'producto': 'Tablet', 'precio': 74.39, 'cantidad': 7},
#  {'producto': 'Cortinas', 'precio': 66.24, 'cantidad': 5},
#  {'producto': 'Lámpara De Mesa', 'precio': 114.83, 'cantidad': 9},
#  {'producto': 'Jarrón Decorativo', 'precio': 87.94, 'cantidad': 2},
#  {'producto': 'Cafetera', 'precio': 62.23, 'cantidad': 1},
#  {'producto': 'Auriculares', 'precio': 32.81, 'cantidad': 11},
#  {'producto': 'Smartwatch', 'precio': 70.66, 'cantidad': 7},
#  {'producto': 'Alfombra', 'precio': 41.72, 'cantidad': 8},
#  {'producto': 'Adorno De Pared', 'precio': 67.75, 'cantidad': 9},
#  {'producto': 'Lámpara De Mesa', 'precio': 35.43, 'cantidad': 2},
#  {'producto': 'Cortinas', 'precio': 84.04, 'cantidad': 3},
#  {'producto': 'Lámpara De Mesa', 'precio': 76.32, 'cantidad': 7},
#  {'producto': 'Secadora', 'precio': 69.58, 'cantidad': 7},
#  {'producto': 'Secadora', 'precio': 33.55, 'cantidad': 3},
#  {'producto': 'Aspiradora', 'precio': 115.24, 'cantidad': 3},
#  {'producto': 'Aspiradora', 'precio': 87.32, 'cantidad': 7},
#  {'producto': 'Consola De Videojuegos', 'precio': 100.69, 'cantidad': 7},
#  {'producto': 'Smartwatch', 'precio': 79.37, 'cantidad': 10},
#  {'producto': 'Proyector', 'precio': 120.34, 'cantidad': 1},
#  {'producto': 'Espejo Decorativo', 'precio': 40.76, 'cantidad': 8},
#  {'producto': 'Alfombra', 'precio': 56.78, 'cantidad': 9},
#  {'producto': 'Rincón De Plantas', 'precio': 77.3, 'cantidad': 7},
#  {'producto': 'Lámpara De Mesa', 'precio': 72.5, 'cantidad': 1},
#  {'producto': 'Lámpara De Mesa', 'precio': 71.17, 'cantidad': 10},
#  {'producto': 'Heladera', 'precio': 88.78, 'cantidad': 2},
#  {'producto': 'Secadora', 'precio': 42.59, 'cantidad': 12},
#  {'producto': 'Auriculares', 'precio': 122.56, 'cantidad': 6},
#  {'producto': 'Laptop', 'precio': 83.25, 'cantidad': 6},
#  {'producto': 'Laptop', 'precio': 30.16, 'cantidad': 6},
#  {'producto': 'Smartphone', 'precio': 123.6, 'cantidad': 12},
#  {'producto': 'Jarrón Decorativo', 'precio': 94.75, 'cantidad': 1},
#  {'producto': 'Freidora Eléctrica', 'precio': 38.12, 'cantidad': 2},
#  {'producto': 'Auriculares', 'precio': 92.91, 'cantidad': 11},
#  {'producto': 'Laptop', 'precio': 124.95, 'cantidad': 11},
#  {'producto': 'Laptop', 'precio': 34.74, 'cantidad': 1},
#  {'producto': 'Auriculares', 'precio': 87.29, 'cantidad': 2},
#  {'producto': 'Lavadora', 'precio': 87.65, 'cantidad': 2},
#  {'producto': 'Aspiradora', 'precio': 34.1, 'cantidad': 3},
#  {'producto': 'Freidora Eléctrica', 'precio': 103.64, 'cantidad': 10},
#  {'producto': 'Batidora', 'precio': 88.23, 'cantidad': 11},
#  {'producto': 'Televisor', 'precio': 34.23, 'cantidad': 4},
#  {'producto': 'Rincón De Plantas', 'precio': 102.85, 'cantidad': 3},
#  {'producto': 'Lámpara De Mesa', 'precio': 96.45, 'cantidad': 1},
#  {'producto': 'Cortinas', 'precio': 119.55, 'cantidad': 7},
#  {'producto': 'Cortinas', 'precio': 42.74, 'cantidad': 12},
#  {'producto': 'Adorno De Pared', 'precio': 66.0, 'cantidad': 4},
#  {'producto': 'Elementos De Cerámica', 'precio': 52.97, 'cantidad': 2},
#  {'producto': 'Lavadora', 'precio': 49.69, 'cantidad': 12},
#  {'producto': 'Secadora', 'precio': 124.09, 'cantidad': 4},
#  {'producto': 'Lavadora', 'precio': 37.2, 'cantidad': 10},
#  {'producto': 'Cafetera', 'precio': 31.94, 'cantidad': 11},
#  {'producto': 'Plancha De Vapor', 'precio': 76.06, 'cantidad': 9},
#  {'producto': 'Freidora Eléctrica', 'precio': 88.9, 'cantidad': 6},
#  {'producto': 'Batidora', 'precio': 38.51, 'cantidad': 9},
#  {'producto': 'Parlantes Bluetooth', 'precio': 79.11, 'cantidad': 3},
#  {'producto': 'Auriculares', 'precio': 122.8, 'cantidad': 3},
#  {'producto': 'Rincón De Plantas', 'precio': 60.89, 'cantidad': 1},
#  {'producto': 'Cortinas', 'precio': 26.29, 'cantidad': 7},
#  {'producto': 'Batidora', 'precio': 123.83, 'cantidad': 12},
#  {'producto': 'Cafetera', 'precio': 101.98, 'cantidad': 2},
#  {'producto': 'Consola De Videojuegos', 'precio': 46.08, 'cantidad': 7},
#  {'producto': 'Smartwatch', 'precio': 80.84, 'cantidad': 8},
#  {'producto': 'Tablet', 'precio': 63.88, 'cantidad': 8},
#  {'producto': 'Tablet', 'precio': 95.9, 'cantidad': 2},
#  {'producto': 'Elementos De Cerámica', 'precio': 93.84, 'cantidad': 8},
#  {'producto': 'Cuadro Decorativo', 'precio': 78.91, 'cantidad': 8},
#  {'producto': 'Aspiradora', 'precio': 68.73, 'cantidad': 5},
#  {'producto': 'Televisor', 'precio': 54.4, 'cantidad': 5},
#  {'producto': 'Televisor', 'precio': 52.6, 'cantidad': 2},
#  {'producto': 'Lámpara De Mesa', 'precio': 55.79, 'cantidad': 1},
#  {'producto': 'Lámpara De Mesa', 'precio': 50.98, 'cantidad': 3},
#  {'producto': 'Heladera', 'precio': 62.93, 'cantidad': 1},
#  {'producto': 'Cafetera', 'precio': 58.81, 'cantidad': 10},
#  {'producto': 'Plancha De Vapor', 'precio': 56.8, 'cantidad': 8},
#  {'producto': 'Cafetera', 'precio': 118.03, 'cantidad': 5},
#  {'producto': 'Secadora', 'precio': 42.03, 'cantidad': 11},
#  {'producto': 'Consola De Videojuegos', 'precio': 122.79, 'cantidad': 6},
#  {'producto': 'Cámara Digital', 'precio': 60.29, 'cantidad': 6},
#  {'producto': 'Tablet', 'precio': 117.89, 'cantidad': 1},
#  {'producto': 'Cámara Digital', 'precio': 63.89, 'cantidad': 1},
#  {'producto': 'Alfombra', 'precio': 107.8, 'cantidad': 7},
#  {'producto': 'Cortinas', 'precio': 71.03, 'cantidad': 7},
#  {'producto': 'Horno Eléctrico', 'precio': 122.69, 'cantidad': 10},
#  {'producto': 'Secadora', 'precio': 105.8, 'cantidad': 3},
#  {'producto': 'Cafetera', 'precio': 88.26, 'cantidad': 1},
#  {'producto': 'Proyector', 'precio': 124.37, 'cantidad': 8},
#  {'producto': 'Proyector', 'precio': 34.39, 'cantidad': 7},
#  {'producto': 'Cámara Digital', 'precio': 42.17, 'cantidad': 8},
#  {'producto': 'Auriculares', 'precio': 32.0, 'cantidad': 1},
#  {'producto': 'Parlantes Bluetooth', 'precio': 98.28, 'cantidad': 5},
#  {'producto': 'Elementos De Cerámica', 'precio': 45.86, 'cantidad': 6},
#  {'producto': 'Alfombra', 'precio': 45.21, 'cantidad': 6},
#  {'producto': 'Jarrón Decorativo', 'precio': 94.59, 'cantidad': 5},
#  {'producto': 'Lámpara De Mesa', 'precio': 99.85, 'cantidad': 3},
#  {'producto': 'Cortinas', 'precio': 107.96, 'cantidad': 9},
#  {'producto': 'Cortinas', 'precio': 45.79, 'cantidad': 7},
#  {'producto': 'Aspiradora', 'precio': 69.06, 'cantidad': 11},
#  {'producto': 'Cafetera', 'precio': 37.32, 'cantidad': 2},
#  {'producto': 'Aspiradora', 'precio': 51.46, 'cantidad': 4},
#  {'producto': 'Laptop', 'precio': 104.48, 'cantidad': 5},
#  {'producto': 'Laptop', 'precio': 77.38, 'cantidad': 1},
#  {'producto': 'Smartphone', 'precio': 76.29, 'cantidad': 11},
#  {'producto': 'Lámpara De Mesa', 'precio': 61.03, 'cantidad': 6},
#  {'producto': 'Espejo Decorativo', 'precio': 76.31, 'cantidad': 5},
#  {'producto': 'Horno Eléctrico', 'precio': 65.16, 'cantidad': 4},
#  {'producto': 'Batidora', 'precio': 108.94, 'cantidad': 6},
#  {'producto': 'Lavadora', 'precio': 37.39, 'cantidad': 1},
#  {'producto': 'Microondas', 'precio': 122.22, 'cantidad': 11},
#  {'producto': 'Aspiradora', 'precio': 54.94, 'cantidad': 3},
#  {'producto': 'Proyector', 'precio': 41.79, 'cantidad': 7},
#  {'producto': 'Parlantes Bluetooth', 'precio': 83.34, 'cantidad': 7},
#  {'producto': 'Consola De Videojuegos', 'precio': 49.74, 'cantidad': 9},
#  {'producto': 'Auriculares', 'precio': 46.72, 'cantidad': 11},
#  {'producto': 'Auriculares', 'precio': 100.58, 'cantidad': 7},
#  {'producto': 'Lámpara De Mesa', 'precio': 82.25, 'cantidad': 8},
#  {'producto': 'Rincón De Plantas', 'precio': 38.89, 'cantidad': 2},
#  {'producto': 'Batidora', 'precio': 119.03, 'cantidad': 8},
#  {'producto': 'Cafetera', 'precio': 67.0, 'cantidad': 11},
#  {'producto': 'Plancha De Vapor', 'precio': 29.68, 'cantidad': 1},
#  {'producto': 'Microondas', 'precio': 65.99, 'cantidad': 8},
#  {'producto': 'Freidora Eléctrica', 'precio': 89.52, 'cantidad': 10},
#  {'producto': 'Heladera', 'precio': 29.17, 'cantidad': 2},
#  {'producto': 'Smartwatch', 'precio': 70.23, 'cantidad': 5},
#  {'producto': 'Alfombra', 'precio': 52.55, 'cantidad': 11},
#  {'producto': 'Secadora', 'precio': 110.21, 'cantidad': 11},
#  {'producto': 'Plancha De Vapor', 'precio': 60.38, 'cantidad': 4},
#  {'producto': 'Aspiradora', 'precio': 92.52, 'cantidad': 1},
#  {'producto': 'Tablet', 'precio': 43.2, 'cantidad': 4},
#  {'producto': 'Rincón De Plantas', 'precio': 32.26, 'cantidad': 8},
#  {'producto': 'Alfombra', 'precio': 112.82, 'cantidad': 9},
#  {'producto': 'Aspiradora', 'precio': 110.58, 'cantidad': 4},
#  {'producto': 'Batidora', 'precio': 66.73, 'cantidad': 8},
#  {'producto': 'Microondas', 'precio': 82.6, 'cantidad': 10},
#  {'producto': 'Auriculares', 'precio': 117.6, 'cantidad': 3},
#  {'producto': 'Auriculares', 'precio': 73.7, 'cantidad': 10},
#  {'producto': 'Rincón De Plantas', 'precio': 115.15, 'cantidad': 11},
#  {'producto': 'Espejo Decorativo', 'precio': 119.87, 'cantidad': 10},
#  {'producto': 'Lavadora', 'precio': 118.77, 'cantidad': 8},
#  {'producto': 'Plancha De Vapor', 'precio': 110.3, 'cantidad': 9},
#  {'producto': 'Freidora Eléctrica', 'precio': 87.64, 'cantidad': 7},
#  {'producto': 'Laptop', 'precio': 36.36, 'cantidad': 7},
#  {'producto': 'Smartphone', 'precio': 76.69, 'cantidad': 3},
#  {'producto': 'Tablet', 'precio': 53.22, 'cantidad': 7},
#  {'producto': 'Lámpara De Mesa', 'precio': 95.05, 'cantidad': 1},
#  {'producto': 'Cuadro Decorativo', 'precio': 119.07, 'cantidad': 12},
#  {'producto': 'Espejo Decorativo', 'precio': 65.35, 'cantidad': 10},
#  {'producto': 'Jarrón Decorativo', 'precio': 96.24, 'cantidad': 11},
#  {'producto': 'Microondas', 'precio': 90.55, 'cantidad': 4},
#  {'producto': 'Plancha De Vapor', 'precio': 90.85, 'cantidad': 2},
#  {'producto': 'Horno Eléctrico', 'precio': 85.42, 'cantidad': 11},
#  {'producto': 'Televisor', 'precio': 38.98, 'cantidad': 11},
#  {'producto': 'Proyector', 'precio': 87.64, 'cantidad': 2},
#  {'producto': 'Smartphone', 'precio': 56.73, 'cantidad': 1},
#  {'producto': 'Parlantes Bluetooth', 'precio': 48.89, 'cantidad': 12},
#  {'producto': 'Lámpara De Mesa', 'precio': 42.17, 'cantidad': 8},
#  {'producto': 'Alfombra', 'precio': 91.25, 'cantidad': 2},
#  {'producto': 'Cuadro Decorativo', 'precio': 47.37, 'cantidad': 9},
#  {'producto': 'Rincón De Plantas', 'precio': 119.89, 'cantidad': 4},
#  {'producto': 'Lámpara De Mesa', 'precio': 98.0, 'cantidad': 12},
#  {'producto': 'Plancha De Vapor', 'precio': 37.94, 'cantidad': 8},
#  {'producto': 'Microondas', 'precio': 96.53, 'cantidad': 1},
#  {'producto': 'Freidora Eléctrica', 'precio': 58.26, 'cantidad': 2},
#  {'producto': 'Cámara Digital', 'precio': 118.02, 'cantidad': 1},
#  {'producto': 'Lámpara De Mesa', 'precio': 97.04, 'cantidad': 12},
#  {'producto': 'Lámpara De Mesa', 'precio': 119.55, 'cantidad': 3},
#  {'producto': 'Horno Eléctrico', 'precio': 118.26, 'cantidad': 11},
#  {'producto': 'Heladera', 'precio': 115.09, 'cantidad': 2},
#  {'producto': 'Tablet', 'precio': 81.56, 'cantidad': 8},
#  {'producto': 'Auriculares', 'precio': 38.79, 'cantidad': 7},
#  {'producto': 'Jarrón Decorativo', 'precio': 39.89, 'cantidad': 2},
#  {'producto': 'Alfombra', 'precio': 60.74, 'cantidad': 12},
#  {'producto': 'Horno Eléctrico', 'precio': 30.51, 'cantidad': 3},
#  {'producto': 'Plancha De Vapor', 'precio': 73.95, 'cantidad': 4},
#  {'producto': 'Cámara Digital', 'precio': 46.25, 'cantidad': 8},
#  {'producto': 'Televisor', 'precio': 108.25, 'cantidad': 8},
#  {'producto': 'Auriculares', 'precio': 49.7, 'cantidad': 3},
#  {'producto': 'Televisor', 'precio': 118.65, 'cantidad': 5},
#  {'producto': 'Lámpara De Mesa', 'precio': 49.91, 'cantidad': 6},
#  {'producto': 'Adorno De Pared', 'precio': 37.38, 'cantidad': 6},
#  {'producto': 'Lámpara De Mesa', 'precio': 79.34, 'cantidad': 1},
#  {'producto': 'Espejo Decorativo', 'precio': 26.33, 'cantidad': 7},
#  {'producto': 'Lámpara De Mesa', 'precio': 95.05, 'cantidad': 3},
#  {'producto': 'Freidora Eléctrica', 'precio': 89.99, 'cantidad': 6},
#  ...]

# %% [markdown]
# # Actividad 2 Etapa 2

# %% [markdown]
# **Transformación de Datos**: Aplicar filtros y transformaciones para crear una
# tabla de ventas que muestre solo los productos con alto rendimiento.

# %%
tabla_por_producto = ( #creo una tabla que agrupa por producto y suma el total de los ingresos , las cantidades y la cantidad de operaciones realizadas
    ventas_perf.groupby("producto", as_index=False)
          .agg(
              ingresos_totales=("ingreso", "sum"),
              unidades_totales=("cantidad", "sum"),
              registros=("producto", "size"),
          )
)
tabla_por_producto.sort_values(by=['ingresos_totales','registros'], ascending=False, inplace=True)
tabla_por_producto.head(10)
# Out:
#              producto  ingresos_totales  unidades_totales  registros
# 19    Lámpara De Mesa          82276.38            1112.0        176
# 3         Auriculares          74175.58             958.0        143
# 20         Microondas          72562.89             912.0        135
# 5            Cafetera          59607.31             765.0        117
# 9   Cuadro Decorativo          54297.60             726.0        100
# 26         Smartphone          54132.44             665.0        101
# 25           Secadora          52115.45             696.0        100
# 16  Jarrón Decorativo          51130.88             672.0        100
# 4            Batidora          50979.20             672.0        100
# 24  Rincón De Plantas          50456.45             691.0        101

# %%
p80_ingreso = tabla_por_producto["ingresos_totales"].quantile( #me indica el valor de ingresos_totales a partir del cual se concentran el 80% de los ingresos
    q=0.80,                # q indica el percentil deseado (0.80 = 80% de los datos por debajo)
    interpolation="linear" # si el percentil no coincide exactamente con un valor real del dataset,
                           # 'linear' interpola entre los dos valores vecinos.
                           # Ejemplo: si el 80% cae entre 4000 y 5000,
                           # calcula un valor proporcional, por ejemplo 4200.
                           # Otros métodos posibles:
                           #  - 'lower': toma el menor de los dos valores (4000)
                           #  - 'higher': toma el mayor (5000)
                           #  - 'nearest': el más cercano al percentil
                           #  - 'midpoint': el punto medio exacto (4500)
)
print(f"Umbral (percentil 80) de ingreso_total: {float(p80_ingreso):,.2f}")
# Out:
# Umbral (percentil 80) de ingreso_total: 52,518.85

# %%
ventas_top = ( #creo una tabla que me muestre los productos que concentran el 80% de los ingresos de tabla_por_producto
    tabla_por_producto

    .query(
        "ingresos_totales >= @p80_ingreso",  # expr: filtra filas donde ingreso_total es al menos el umbral del P80
        engine="python"                   # motor de evaluación (usar 'numexpr' si lo tenés y querés performance)

    )

    .sort_values(
        by=["ingresos_totales", "unidades_totales"],  # primero ordena por ingreso_total, luego desempata por unidades
        ascending=[False, False],          # ambos en orden descendente (mayor → menor)
        na_position="last",                # coloca NaN al final (útil si alguna métrica quedó en NaN)
        ignore_index=True                  # reindexa el resultado secuencialmente (0..n-1)

    )
)
ventas_top
# Out:
#             producto  ingresos_totales  unidades_totales  registros
# 0    Lámpara De Mesa          82276.38            1112.0        176
# 1        Auriculares          74175.58             958.0        143
# 2         Microondas          72562.89             912.0        135
# 3           Cafetera          59607.31             765.0        117
# 4  Cuadro Decorativo          54297.60             726.0        100
# 5         Smartphone          54132.44             665.0        101

# %% [markdown]
# # Actividad 3 Etapa 2

# %% [markdown]
# **Agregación**: Resumir las ventas por categoría de producto y analizar los
# ingresos generados.

# %%
ventas_perf.head(5)
# Out:
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro Decorativo   69.94       5.0  2024-01-02
# 1       811    Lámpara De Mesa  105.10       5.0  2024-01-02
# 2      1156           Secadora   97.96       3.0  2024-01-02
# 3      1372           Heladera  114.35       8.0  2024-01-02
# 4      1546           Secadora  106.21       4.0  2024-01-02
#
#            categoria  ingreso
# 0         Decoración   349.70
# 1         Decoración   525.50
# 2  Electrodomésticos   293.88
# 3  Electrodomésticos   914.80
# 4  Electrodomésticos   424.84

# %%
resumen_cat = ( #creo una tabla que agrupa por categoria y suma el total de los ingresos , las cantidades y la cantidad de operaciones realizadas y la ordena por ingresos
    ventas_perf.groupby('categoria', as_index=False)
          .agg(ingresos=('ingreso','sum'),
               unidades=('cantidad','sum'),
               transacciones=('id_venta','count'))
          .sort_values('ingresos', ascending=False)
)
total_ingresos = resumen_cat['ingresos'].sum()
#  Participación de cada categoría sobre el total
resumen_cat['participacion_%'] = (resumen_cat['ingresos'] / total_ingresos * 100).round(2)

#  Ticket promedio por venta = ingresos / transacciones
resumen_cat = resumen_cat.assign(
    ticket_promedio_por_venta = resumen_cat['ingresos'] / resumen_cat['transacciones'])

#precio promedio = ingresos/unidades
resumen_cat = resumen_cat.assign(
    precio_promedio = resumen_cat['ingresos'] / resumen_cat['unidades'])

resumen_cat
# Out:
#            categoria   ingresos  unidades  transacciones  participacion_%  \
# 1  Electrodomésticos  505299.63    6592.0           1000            34.44
# 2        Electrónica  482577.80    6413.0            998            32.89
# 0         Decoración  479216.09    6490.0           1000            32.66
#
#    ticket_promedio_por_venta  precio_promedio
# 1                  505.29963        76.653463
# 2                  483.54489        75.249930
# 0                  479.21609        73.839151
